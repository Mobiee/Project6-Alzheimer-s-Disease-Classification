# %%
from scipy.io import loadmat
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.set_printoptions(threshold=np.inf)

# %%
from scipy.io import loadmat
import numpy as np
import warnings
warnings.filterwarnings("ignore")
# reading file
data=loadmat("IJCNN_MCAD_AFQ_competition.mat", mat_dtype=True)

# %%
# data.items()

# %%
# This matrix contains diagnosis information for each subject. Numeral 1 means normal control (NC). 
# Similarly, Numeral 2 
# represents mild cognitive impairment (MCI), and numeral 3 represents Alzheimer's disease patients (AD).
train_diagnose=data["train_diagnose"]
print("Shape of Train diagnose: ",train_diagnose.shape)
train_diagnose[1:5]
# Out:
# Shape of Train diagnose:  (700, 1)
# array([[1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
df_td=pd.DataFrame(train_diagnose,columns=["train_diagnose"])

# %%
# exploring fgnames 
fgnames=data["fgnames"]

print("Shape of fgnames: ",fgnames.shape)
fgnames
# Out:
# Shape of fgnames:  (1, 20)
# array([[array(['Left Thalamic Radiation'], dtype='<U23'),
#         array(['Right Thalamic Radiation'], dtype='<U24'),
#         array(['Left Corticospinal'], dtype='<U18'),
#         array(['Right Corticospinal'], dtype='<U19'),
#         array(['Left Cingulum Cingulate'], dtype='<U23'),
#         array(['Right Cingulum Cingulate'], dtype='<U24'),
#         array(['Left Cingulum Hippocampus'], dtype='<U25'),
#         array(['Right Cingulum Hippocampus'], dtype='<U26'),
#         array(['Callosum Forceps Major'], dtype='<U22'),
#         array(['Callosum Forceps Minor'], dtype='<U22'),
#         array(['Left IFOF'], dtype='<U9'),
#         array(['Right IFOF'], dtype='<U10'),
#         array(['Left ILF'], dtype='<U8'),
#         array(['Right ILF'], dtype='<U9'),
#         array(['Left SLF'], dtype='<U8'),
#         array(['Right SLF'], dtype='<U9'),
#         array(['Left Uncinate'], dtype='<U13'),
#         array(['Right Uncinate'], dtype='<U14'),
#         array(['Left Arcuate'], dtype='<U12'),
#         array(['Right Arcuate'], dtype='<U13')]], dtype=object)

# %%
# Here we provide age and gender information for each subject.
# The 1st column is gender in which 0 represents male and 1 represents female. The 2nd column is age.
train_population=data["train_population"]
print("Shape of train population: ",train_population.shape)
train_population
# Out:
# Shape of train population:  (700, 2)
# array([[ 0., 66.],
#        [ 1., 67.],
#        [ 0., 72.],
#        [ 0., 76.],
#        [ 1., 61.],
#        [ 1., 63.],
#        [ 0., 57.],
#        [ 1., 55.],
#        [ 1., 82.],
#        [ 1., 72.],
#        [ 1., 76.],
#        [ 0., 65.],
#        [ 0., 64.],
#        [ 1., 66.],
#        [ 1., 67.],
#        [ 1., 63.],
#        [ 0., 62.],
#        [ 0., 64.],
#        [ 0., 73.],
#        [ 1., 76.],
#        [ 0., 65.],
#        [ 0., 80.],
#        [ 0., 77.],
#        [ 1., 64.],
#        [ 1., 70.],
#        [ 1., 68.],
#        [ 0., 79.],
#        [ 1., 78.],
#        [ 0., 69.],
#        [ 1., 73.],
#        [ 1., 81.],
#        [ 0., 68.],
#        [ 0., 70.],
#        [ 0., 63.],
#        [ 0., 58.],
#        [ 1., 69.],
#        [ 0., 79.],
#        [ 0., 51.],
#        [ 0., 80.],
#        [ 1., 64.],
#        [ 1., 68.],
#        [ 0., 65.],
#        [ 1., 65.],
#        [ 0., 79.],
#        [ 0., 61.],
#        [ 1., 61.],
#        [ 0., 73.],
#        [ 1., 62.],
#        [ 1., 76.],
#        [ 0., 72.],
#        [ 1., 60.],
#        [ 1., 62.],
#        [ 1., 48.],
#        [ 1., 71.],
#        [ 1., 72.],
#        [ 0., 66.],
#        [ 0., 75.],
#        [ 1., 70.],
#        [ 1., 85.],
#        [ 1., 76.],
#        [ 1., 72.],
#        [ 1., 62.],
#        [ 0., 78.],
#        [ 1., 73.],
#        [ 0., 77.],
#        [ 0., 79.],
#        [ 0., 63.],
#        [ 0., 83.],
#        [ 1., 81.],
#        [ 1., 77.],
#        [ 1., 66.],
#        [ 0., 67.],
#        [ 1., 61.],
#        [ 0., 76.],
#        [ 1., 77.],
#        [ 1., 66.],
#        [ 0., 87.],
#        [ 1., 81.],
#        [ 0., 72.],
#        [ 1., 76.],
#        [ 1., 73.],
#        [ 0., 55.],
#        [ 1., 62.],
#        [ 1., 64.],
#        [ 0., 60.],
#        [ 0., 83.],
#        [ 1., 64.],
#        [ 1., 76.],
#        [ 0., 59.],
#        [ 1., 53.],
#        [ 0., 58.],
#        [ 0., 76.],
#        [ 1., 69.],
#        [ 1., 81.],
#        [ 0., 62.],
#        [ 0., 57.],
#        [ 1., 62.],
#        [ 1., 67.],
#        [ 0., 70.],
#        [ 1., 63.],
#        [ 1., 70.],
#        [ 0., 73.],
#        [ 0., 74.],
#        [ 1., 65.],
#        [ 0., 88.],
#        [ 0., 81.],
#        [ 0., 61.],
#        [ 0., 70.],
#        [ 1., 62.],
#        [ 0., 78.],
#        [ 1., 67.],
#        [ 1., 68.],
#        [ 0., 60.],
#        [ 0., 60.],
#        [ 1., 71.],
#        [ 1., 71.],
#        [ 0., 77.],
#        [ 0., 68.],
#        [ 1., 73.],
#        [ 0., 73.],
#        [ 1., 70.],
#        [ 1., 68.],
#        [ 0., 67.],
#        [ 0., 65.],
#        [ 0., 69.],
#        [ 1., 75.],
#        [ 0., 64.],
#        [ 0., 76.],
#        [ 0., 79.],
#        [ 0., 84.],
#        [ 1., 88.],
#        [ 0., 83.],
#        [ 0., 81.],
#        [ 0., 70.],
#        [ 1., 79.],
#        [ 1., 79.],
#        [ 0., 74.],
#        [ 1., 59.],
#        [ 1., 71.],
#        [ 0., 70.],
#        [ 1., 80.],
#        [ 0., 60.],
#        [ 1., 66.],
#        [ 1., 63.],
#        [ 0., 81.],
#        [ 1., 80.],
#        [ 1., 77.],
#        [ 1., 63.],
#        [ 0., 70.],
#        [ 1., 65.],
#        [ 1., 60.],
#        [ 1., 79.],
#        [ 1., 81.],
#        [ 1., 78.],
#        [ 1., 71.],
#        [ 0., 76.],
#        [ 1., 65.],
#        [ 1., 75.],
#        [ 1., 60.],
#        [ 0., 72.],
#        [ 0., 80.],
#        [ 1., 65.],
#        [ 1., 67.],
#        [ 1., 59.],
#        [ 0., 73.],
#        [ 1., 81.],
#        [ 1., 75.],
#        [ 0., 66.],
#        [ 1., 79.],
#        [ 1., 72.],
#        [ 1., 69.],
#        [ 0., 72.],
#        [ 1., 69.],
#        [ 1., 62.],
#        [ 1., 60.],
#        [ 0., 55.],
#        [ 1., 74.],
#        [ 0., 74.],
#        [ 0., 63.],
#        [ 0., 60.],
#        [ 1., 61.],
#        [ 0., 62.],
#        [ 1., 63.],
#        [ 1., 63.],
#        [ 1., 59.],
#        [ 1., 73.],
#        [ 0., 73.],
#        [ 0., 67.],
#        [ 1., 58.],
#        [ 1., 59.],
#        [ 0., 80.],
#        [ 1., 62.],
#        [ 0., 59.],
#        [ 0., 48.],
#        [ 1., 79.],
#        [ 1., 82.],
#        [ 0., 58.],
#        [ 1., 62.],
#        [ 1., 65.],
#        [ 1., 60.],
#        [ 0., 68.],
#        [ 1., 73.],
#        [ 0., 70.],
#        [ 0., 57.],
#        [ 1., 63.],
#        [ 1., 60.],
#        [ 0., 51.],
#        [ 1., 68.],
#        [ 1., 64.],
#        [ 1., 70.],
#        [ 1., 77.],
#        [ 1., 61.],
#        [ 1., 77.],
#        [ 0., 71.],
#        [ 1., 60.],
#        [ 1., 60.],
#        [ 1., 77.],
#        [ 0., 74.],
#        [ 1., 66.],
#        [ 1., 58.],
#        [ 0., 72.],
#        [ 1., 57.],
#        [ 1., 51.],
#        [ 0., 59.],
#        [ 0., 60.],
#        [ 0., 72.],
#        [ 1., 77.],
#        [ 1., 74.],
#        [ 0., 58.],
#        [ 0., 71.],
#        [ 1., 55.],
#        [ 1., 70.],
#        [ 1., 80.],
#        [ 0., 60.],
#        [ 0., 63.],
#        [ 0., 60.],
#        [ 0., 57.],
#        [ 0., 72.],
#        [ 1., 60.],
#        [ 0., 70.],
#        [ 0., 77.],
#        [ 0., 65.],
#        [ 1., 55.],
#        [ 0., 76.],
#        [ 0., 71.],
#        [ 1., 66.],
#        [ 0., 63.],
#        [ 0., 83.],
#        [ 1., 73.],
#        [ 1., 75.],
#        [ 1., 65.],
#        [ 1., 81.],
#        [ 1., 59.],
#        [ 1., 72.],
#        [ 0., 62.],
#        [ 0., 60.],
#        [ 0., 64.],
#        [ 1., 64.],
#        [ 1., 64.],
#        [ 0., 61.],
#        [ 1., 65.],
#        [ 1., 60.],
#        [ 1., 64.],
#        [ 1., 68.],
#        [ 1., 62.],
#        [ 1., 60.],
#        [ 1., 60.],
#        [ 1., 63.],
#        [ 1., 60.],
#        [ 1., 53.],
#        [ 1., 69.],
#        [ 0., 66.],
#        [ 1., 60.],
#        [ 1., 79.],
#        [ 1., 71.],
#        [ 1., 63.],
#        [ 1., 70.],
#        [ 1., 68.],
#        [ 1., 61.],
#        [ 0., 70.],
#        [ 1., 59.],
#        [ 0., 58.],
#        [ 0., 71.],
#        [ 0., 72.],
#        [ 1., 79.],
#        [ 1., 70.],
#        [ 1., 62.],
#        [ 0., 78.],
#        [ 1., 78.],
#        [ 0., 71.],
#        [ 0., 66.],
#        [ 0., 61.],
#        [ 0., 66.],
#        [ 0., 60.],
#        [ 1., 60.],
#        [ 1., 64.],
#        [ 1., 67.],
#        [ 1., 58.],
#        [ 0., 75.],
#        [ 1., 54.],
#        [ 0., 80.],
#        [ 1., 79.],
#        [ 1., 68.],
#        [ 1., 82.],
#        [ 0., 70.],
#        [ 0., 60.],
#        [ 1., 72.],
#        [ 1., 66.],
#        [ 0., 81.],
#        [ 1., 60.],
#        [ 1., 78.],
#        [ 1., 73.],
#        [ 1., 60.],
#        [ 0., 67.],
#        [ 1., 70.],
#        [ 1., 66.],
#        [ 0., 60.],
#        [ 0., 79.],
#        [ 0., 76.],
#        [ 0., 60.],
#        [ 0., 67.],
#        [ 1., 66.],
#        [ 1., 78.],
#        [ 1., 61.],
#        [ 0., 62.],
#        [ 1., 68.],
#        [ 0., 60.],
#        [ 1., 62.],
#        [ 0., 60.],
#        [ 0., 80.],
#        [ 0., 60.],
#        [ 1., 76.],
#        [ 0., 60.],
#        [ 0., 62.],
#        [ 1., 76.],
#        [ 1., 58.],
#        [ 1., 75.],
#        [ 1., 72.],
#        [ 1., 63.],
#        [ 0., 78.],
#        [ 1., 69.],
#        [ 0., 70.],
#        [ 1., 81.],
#        [ 0., 59.],
#        [ 0., 66.],
#        [ 1., 63.],
#        [ 0., 66.],
#        [ 1., 63.],
#        [ 1., 58.],
#        [ 1., 64.],
#        [ 1., 77.],
#        [ 0., 60.],
#        [ 1., 68.],
#        [ 0., 75.],
#        [ 0., 56.],
#        [ 0., 72.],
#        [ 1., 62.],
#        [ 1., 70.],
#        [ 1., 75.],
#        [ 1., 72.],
#        [ 0., 72.],
#        [ 1., 63.],
#        [ 1., 69.],
#        [ 1., 60.],
#        [ 0., 66.],
#        [ 0., 51.],
#        [ 0., 67.],
#        [ 0., 57.],
#        [ 0., 71.],
#        [ 0., 57.],
#        [ 1., 60.],
#        [ 1., 70.],
#        [ 1., 58.],
#        [ 1., 60.],
#        [ 1., 59.],
#        [ 0., 61.],
#        [ 1., 70.],
#        [ 1., 61.],
#        [ 1., 61.],
#        [ 0., 67.],
#        [ 1., 65.],
#        [ 1., 60.],
#        [ 0., 62.],
#        [ 1., 67.],
#        [ 1., 62.],
#        [ 0., 78.],
#        [ 1., 63.],
#        [ 1., 67.],
#        [ 0., 61.],
#        [ 1., 70.],
#        [ 1., 73.],
#        [ 1., 59.],
#        [ 0., 60.],
#        [ 1., 60.],
#        [ 0., 59.],
#        [ 1., 61.],
#        [ 1., 55.],
#        [ 0., 50.],
#        [ 0., 58.],
#        [ 0., 60.],
#        [ 0., 56.],
#        [ 0., 76.],
#        [ 0., 73.],
#        [ 1., 71.],
#        [ 1., 72.],
#        [ 1., 83.],
#        [ 1., 51.],
#        [ 0., 68.],
#        [ 1., 65.],
#        [ 1., 61.],
#        [ 1., 56.],
#        [ 0., 77.],
#        [ 1., 71.],
#        [ 0., 69.],
#        [ 1., 46.],
#        [ 1., 61.],
#        [ 0., 58.],
#        [ 1., 50.],
#        [ 1., 58.],
#        [ 0., 66.],
#        [ 1., 56.],
#        [ 1., 62.],
#        [ 1., 58.],
#        [ 0., 51.],
#        [ 0., 72.],
#        [ 0., 52.],
#        [ 1., 56.],
#        [ 0., 68.],
#        [ 1., 72.],
#        [ 1., 76.],
#        [ 0., 78.],
#        [ 0., 76.],
#        [ 1., 54.],
#        [ 1., 82.],
#        [ 0., 67.],
#        [ 1., 72.],
#        [ 0., 85.],
#        [ 1., 54.],
#        [ 0., 66.],
#        [ 1., 66.],
#        [ 1., 53.],
#        [ 0., 67.],
#        [ 1., 76.],
#        [ 1., 80.],
#        [ 0., 79.],
#        [ 0., 63.],
#        [ 0., 76.],
#        [ 1., 78.],
#        [ 0., 71.],
#        [ 1., 57.],
#        [ 0., 51.],
#        [ 1., 66.],
#        [ 0., 74.],
#        [ 0., 67.],
#        [ 1., 52.],
#        [ 1., 74.],
#        [ 1., 66.],
#        [ 0., 71.],
#        [ 1., 69.],
#        [ 0., 61.],
#        [ 1., 63.],
#        [ 1., 65.],
#        [ 0., 70.],
#        [ 1., 79.],
#        [ 1., 58.],
#        [ 1., 77.],
#        [ 0., 76.],
#        [ 1., 63.],
#        [ 0., 83.],
#        [ 0., 62.],
#        [ 0., 68.],
#        [ 1., 50.],
#        [ 1., 63.],
#        [ 1., 75.],
#        [ 0., 80.],
#        [ 0., 64.],
#        [ 0., 74.],
#        [ 0., 83.],
#        [ 1., 77.],
#        [ 1., 54.],
#        [ 0., 51.],
#        [ 0., 72.],
#        [ 0., 78.],
#        [ 0., 73.],
#        [ 1., 58.],
#        [ 0., 72.],
#        [ 1., 72.],
#        [ 0., 71.],
#        [ 1., 64.],
#        [ 0., 59.],
#        [ 1., 78.],
#        [ 1., 64.],
#        [ 1., 70.],
#        [ 0., 80.],
#        [ 1., 79.],
#        [ 0., 50.],
#        [ 1., 76.],
#        [ 0., 62.],
#        [ 0., 78.],
#        [ 0., 66.],
#        [ 1., 55.],
#        [ 0., 88.],
#        [ 0., 58.],
#        [ 1., 59.],
#        [ 1., 72.],
#        [ 1., 77.],
#        [ 1., 67.],
#        [ 1., 80.],
#        [ 1., 74.],
#        [ 0., 65.],
#        [ 1., 69.],
#        [ 1., 80.],
#        [ 0., 61.],
#        [ 1., 77.],
#        [ 1., 55.],
#        [ 1., 72.],
#        [ 1., 86.],
#        [ 1., 71.],
#        [ 1., 56.],
#        [ 1., 67.],
#        [ 0., 65.],
#        [ 0., 84.],
#        [ 0., 71.],
#        [ 1., 67.],
#        [ 0., 74.],
#        [ 1., 54.],
#        [ 1., 73.],
#        [ 1., 81.],
#        [ 1., 51.],
#        [ 1., 76.],
#        [ 0., 69.],
#        [ 1., 78.],
#        [ 0., 75.],
#        [ 1., 70.],
#        [ 0., 71.],
#        [ 0., 66.],
#        [ 1., 67.],
#        [ 0., 75.],
#        [ 1., 78.],
#        [ 1., 74.],
#        [ 0., 62.],
#        [ 0., 63.],
#        [ 0., 73.],
#        [ 1., 77.],
#        [ 1., 60.],
#        [ 1., 49.],
#        [ 0., 57.],
#        [ 0., 72.],
#        [ 0., 74.],
#        [ 1., 59.],
#        [ 1., 68.],
#        [ 1., 61.],
#        [ 0., 74.],
#        [ 1., 58.],
#        [ 1., 84.],
#        [ 1., 67.],
#        [ 0., 62.],
#        [ 1., 66.],
#        [ 1., 61.],
#        [ 1., 70.],
#        [ 1., 52.],
#        [ 1., 51.],
#        [ 1., 57.],
#        [ 0., 67.],
#        [ 0., 79.],
#        [ 1., 73.],
#        [ 0., 74.],
#        [ 1., 63.],
#        [ 1., 62.],
#        [ 0., 81.],
#        [ 0., 79.],
#        [ 0., 70.],
#        [ 0., 73.],
#        [ 0., 75.],
#        [ 0., 62.],
#        [ 1., 70.],
#        [ 0., 62.],
#        [ 1., 75.],
#        [ 1., 69.],
#        [ 1., 74.],
#        [ 0., 64.],
#        [ 1., 51.],
#        [ 1., 60.],
#        [ 0., 51.],
#        [ 0., 64.],
#        [ 1., 74.],
#        [ 0., 72.],
#        [ 0., 65.],
#        [ 0., 67.],
#        [ 1., 57.],
#        [ 1., 72.],
#        [ 1., 66.],
#        [ 0., 56.],
#        [ 1., 67.],
#        [ 1., 51.],
#        [ 1., 62.],
#        [ 0., 79.],
#        [ 1., 60.],
#        [ 1., 65.],
#        [ 1., 66.],
#        [ 0., 68.],
#        [ 1., 79.],
#        [ 1., 67.],
#        [ 1., 72.],
#        [ 1., 67.],
#        [ 0., 66.],
#        [ 1., 58.],
#        [ 1., 71.],
#        [ 1., 69.],
#        [ 1., 62.],
#        [ 0., 77.],
#        [ 0., 81.],
#        [ 0., 70.],
#        [ 1., 65.],
#        [ 0., 71.],
#        [ 1., 69.],
#        [ 1., 66.],
#        [ 1., 64.],
#        [ 1., 64.],
#        [ 1., 65.],
#        [ 1., 69.],
#        [ 0., 70.],
#        [ 0., 73.],
#        [ 0., 80.],
#        [ 0., 83.],
#        [ 0., 74.],
#        [ 0., 79.],
#        [ 0., 80.],
#        [ 0., 68.],
#        [ 1., 62.],
#        [ 1., 78.],
#        [ 0., 47.],
#        [ 1., 66.],
#        [ 1., 73.],
#        [ 1., 74.],
#        [ 1., 75.],
#        [ 0., 73.],
#        [ 0., 70.],
#        [ 1., 69.],
#        [ 1., 69.],
#        [ 0., 65.],
#        [ 1., 64.],
#        [ 1., 61.],
#        [ 0., 81.],
#        [ 0., 67.],
#        [ 1., 57.],
#        [ 0., 80.],
#        [ 1., 61.],
#        [ 0., 68.],
#        [ 1., 66.],
#        [ 1., 55.],
#        [ 1., 71.],
#        [ 1., 81.],
#        [ 1., 66.],
#        [ 1., 65.],
#        [ 1., 67.],
#        [ 1., 81.],
#        [ 0., 67.],
#        [ 1., 72.],
#        [ 1., 75.],
#        [ 0., 80.],
#        [ 0., 60.],
#        [ 1., 75.],
#        [ 0., 83.],
#        [ 1., 78.],
#        [ 1., 75.],
#        [ 1., 65.],
#        [ 1., 64.],
#        [ 0., 77.],
#        [ 1., 76.],
#        [ 0., 62.],
#        [ 1., 68.],
#        [ 1., 69.],
#        [ 1., 78.],
#        [ 0., 63.],
#        [ 1., 79.],
#        [ 0., 65.],
#        [ 1., 72.],
#        [ 1., 64.],
#        [ 1., 60.],
#        [ 1., 61.],
#        [ 1., 79.],
#        [ 1., 78.],
#        [ 1., 63.],
#        [ 0., 81.],
#        [ 1., 75.],
#        [ 1., 89.],
#        [ 1., 69.],
#        [ 0., 83.],
#        [ 0., 59.],
#        [ 0., 81.],
#        [ 1., 75.],
#        [ 0., 64.],
#        [ 1., 71.],
#        [ 0., 63.],
#        [ 0., 53.],
#        [ 1., 72.],
#        [ 1., 76.],
#        [ 1., 77.],
#        [ 0., 81.]])

# %%
# converting train_diagnose into digits from float.
train_diagnose_list=[int(train_diagnose) for train_diagnose in train_diagnose]
# inserting train population into dataframe
train_population_df=pd.DataFrame(list(train_population),columns=["Gender","Age"])
# converting the float type into digits(int)
train_population_df=train_population_df.astype(int)
# inserting train diagnose into dataframe
train_diagnose_df= pd.DataFrame(list(train_diagnose),columns=["Diagnose"])

train_diagnose_df.head(5)
train_population_df.head(5)
# combining these two datafarmes
Subject_information=pd.concat((train_population_df,train_diagnose_df),axis=1)
Subject_information.head()
# Out:
#    Gender  Age  Diagnose
# 0       0   66       1.0
# 1       1   67       1.0
# 2       0   72       1.0
# 3       0   76       1.0
# 4       1   61       1.0

# %%
# to look at the exploration of the gender in pie chart format.
sns.set(style="darkgrid")
Gender=["Female","Male"]
size=Subject_information["Gender"].value_counts()
colors=["crimson","lightskyblue"]
explode=[0,0.1]
plt.figure(figsize=(20,5))
plt.pie(size,colors=colors,explode=explode,labels=Gender,shadow=True,autopct="%.2f%%")
plt.title("Gender Distrubtion in the Data",fontsize=20)
plt.axis("off")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# looking at gender distrubtion in different classes of NC,MCI and AD.
plt.figure(figsize = (8,10))
sns.countplot(data= Subject_information , hue='Gender', x='Diagnose',palette="Set2").tick_params(axis='x', rotation = 45)

# %%
# box plot to see age distributions in different classes of NC,MCI and AD
# as can be seen the median Age of Nc is around 66,MCI 70 and AD around 68
plt.figure(figsize = (10,12))
sns.boxplot(x='Diagnose', y='Age', data=Subject_information,palette="Set1")
plt.title('Boxplot of Age in Different classes of NC,MCI and AD',fontsize=14)
plt.show()

# %%
# In this matrix, different numbers represent different sites that subjects belong to.
train_sites=data["train_sites"]
print("Shape of train sites: ",train_sites.shape)
train_sites[1:10]
# Out:
# Shape of train sites:  (700, 1)
# array([[1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.],
#        [1.]])

# %%
# This cell provides all
# data processed by AFQ. Each row is a fiber tract whose name can be found in a variable called “fgnames”
print("Shape of train_Set: ",data['train_set'].shape)
# Out:
# Shape of train_Set:  (20, 1)

# %%
# Measurement of FA
fa=data['train_set']['FA']
print(fa.shape)
# Out:
# (20, 1)

# %%
# feature vector of meausrements at their first location

M1=data['train_set']['FA'][0][0]
M2=data['train_set']['MD'][0][0]
M3=data['train_set']['RD'][0][0]
M4=data['train_set']['AD'][0][0]
M5=data['train_set']['CL'][0][0]
M6=data['train_set']['CURVATURE'][0][0]
M7=data['train_set']['TORSION'][0][0]
M8=data['train_set']['VOLUME'][0][0]
M1.shape
# Out:
# (700, 100)

# %%
fa=data['train_set']['FA']
md=data["train_set"]["MD"]
rd=data["train_set"]["RD"]
ad=data["train_set"]["AD"]
cl=data["train_set"]["CL"]
curvature=data["train_set"]["CURVATURE"]
Torsion=data["train_set"]["TORSION"]
volume=data["train_set"]["VOLUME"]

# %%
fa_feature_all_locations=M1
for i in range (1,fa.shape[0]):
    fa_feature_all_locations=np.append(fa_feature_all_locations,data['train_set']['FA'][i][0], axis=1)
print("FA shape:",fa_feature_all_locations.shape)
# Out:
# FA shape: (700, 2000)

# %%
# %%time

# concatenate feature vector of 8 measurements along horizontal direction to obtain measueremnt features from all 20 locations
md_feature_all_locations=M2
for i in range (1,md.shape[0]):
    md_feature_all_locations=np.append(md_feature_all_locations,data['train_set']['MD'][i][0], axis=1)
print("MD shape:",fa_feature_all_locations.shape)

rd_feature_all_locations=M3
for i in range (1,rd.shape[0]):
    rd_feature_all_locations=np.append(rd_feature_all_locations,data['train_set']['RD'][i][0], axis=1)
print("RD shape:",rd_feature_all_locations.shape)

ad_feature_all_locations=M4
for i in range (1,ad.shape[0]):
    ad_feature_all_locations=np.append(ad_feature_all_locations,data['train_set']['AD'][i][0], axis=1)
print("AD shape:",ad_feature_all_locations.shape)

cl_feature_all_locations=M5
for i in range (1,cl.shape[0]):
    cl_feature_all_locations=np.append(cl_feature_all_locations,data['train_set']['CL'][i][0], axis=1)
print("CL shape:",cl_feature_all_locations.shape)

curvature_feature_all_locations=M6
for i in range (1,curvature.shape[0]):
    curvature_feature_all_locations=np.append(curvature_feature_all_locations,data['train_set']['CURVATURE'][i][0], axis=1)
print("Curvature shape:",curvature_feature_all_locations.shape)

Torsion_feature_all_locations=M7
for i in range (1,Torsion.shape[0]):
    Torsion_feature_all_locations=np.append(Torsion_feature_all_locations,data['train_set']['TORSION'][i][0], axis=1)
print("Torsion shape:",Torsion_feature_all_locations.shape)

volume_feature_all_locations=M8
for i in range (1,volume.shape[0]):
    volume_feature_all_locations=np.append(volume_feature_all_locations,data['train_set']['VOLUME'][i][0], axis=1)
print("Volume shape:",volume_feature_all_locations.shape)
# Out:
# MD shape: (700, 2000)
# RD shape: (700, 2000)
# AD shape: (700, 2000)
# CL shape: (700, 2000)
# Curvature shape: (700, 2000)
# Torsion shape: (700, 2000)
# Volume shape: (700, 2000)
# CPU times: user 179 ms, sys: 80.7 ms, total: 259 ms
# Wall time: 257 ms

# %%
def replace_nan_values(measurement):
    # Obtain mean of columns as you need, nanmean is convenient.
    col_mean = np.nanmean(measurement, axis=0)
    # print(col_mean)

    # Find indices that you need to replace
    inds = np.where(np.isnan(measurement))

    # Place column means in the indices. Align the arrays using take
    measurement[inds] = np.take(col_mean, inds[1])
    return measurement

# %%
# Replacing nan values with the mean of each column
fa_feature_all_locations_without_Nan=replace_nan_values(fa_feature_all_locations)
md_feature_all_locations_without_Nan=replace_nan_values(md_feature_all_locations)
rd_feature_all_locations_without_Nan=replace_nan_values(rd_feature_all_locations)
ad_feature_all_locations_without_Nan=replace_nan_values(ad_feature_all_locations)
cl_feature_all_locations_without_Nan=replace_nan_values(cl_feature_all_locations)
curvature_feature_all_locations_without_Nan= replace_nan_values(curvature_feature_all_locations)
Torsion_feature_all_locations_without_Nan=replace_nan_values(Torsion_feature_all_locations)
volume_feature_all_locations_without_Nan=replace_nan_values(volume_feature_all_locations)

# printing the shapes of all fetures after replacing NAN values.
print(fa_feature_all_locations_without_Nan.shape)
print(md_feature_all_locations_without_Nan.shape)
print(rd_feature_all_locations_without_Nan.shape)
print(ad_feature_all_locations_without_Nan.shape)
print(cl_feature_all_locations_without_Nan.shape)
print(curvature_feature_all_locations_without_Nan.shape)
print(Torsion_feature_all_locations_without_Nan.shape)
print(volume_feature_all_locations_without_Nan.shape)
# Out:
# (700, 2000)
# (700, 2000)
# (700, 2000)
# (700, 2000)
# (700, 2000)
# (700, 2000)
# (700, 2000)
# (700, 2000)

# %%
# Normalizing all features 
from sklearn.preprocessing import MinMaxScaler
# Applying MINMAX SCaler in all 8 features
scaler = MinMaxScaler(feature_range = (0, 1)) # to make it range between 1 and 5
# scaler = MinMaxScaler()
scaler.fit(fa_feature_all_locations_without_Nan)
fa_feature_all_locations_scaled=scaler.transform(fa_feature_all_locations_without_Nan)
scaler.fit(md_feature_all_locations_without_Nan)
md_feature_all_locations_scaled=scaler.transform(md_feature_all_locations_without_Nan)
scaler.fit(rd_feature_all_locations_without_Nan)
rd_feature_all_locations_scaled=scaler.transform(rd_feature_all_locations_without_Nan)
scaler.fit(ad_feature_all_locations_without_Nan)
ad_feature_all_locations_scaled=scaler.transform(ad_feature_all_locations_without_Nan)
scaler.fit(cl_feature_all_locations_without_Nan)
cl_feature_all_locations_scaled=scaler.transform(cl_feature_all_locations_without_Nan)
scaler.fit(curvature_feature_all_locations_without_Nan)
curvature_feature_all_locations_scaled=scaler.transform(curvature_feature_all_locations_without_Nan)
scaler.fit(Torsion_feature_all_locations_without_Nan)
Torsion_feature_all_locations_scaled=scaler.transform(Torsion_feature_all_locations_without_Nan)
scaler.fit(volume_feature_all_locations_without_Nan)
volume_feature_all_locations_scaled=scaler.transform(volume_feature_all_locations_without_Nan)

# %%
volume_feature_all_locations_scaled[1][1]
# Out:
# 0.5714285714285714

# %%
volume_feature_all_locations_scaled.shape[0]
# Out:
# 700

# %%
# correcting mistakes of not using replaced nan values 
combined_features_without_Scaling=np.concatenate((fa_feature_all_locations_without_Nan,md_feature_all_locations_without_Nan,rd_feature_all_locations_without_Nan, 
                        ad_feature_all_locations_without_Nan,cl_feature_all_locations_without_Nan,curvature_feature_all_locations_without_Nan,
                        Torsion_feature_all_locations_without_Nan,volume_feature_all_locations_without_Nan),axis=1)

# %%
# combining Features and train diagnose 
CombinedFeatDig=np.concatenate((combined_features_without_Scaling,train_diagnose),axis=1)

# %%
# separating NC,MCI and AD from the data
NC = np.where(CombinedFeatDig[:,-1] == 1)[0]
# NC shape after separting it from two other lables
print(NC.shape)

NMCI = np.where(CombinedFeatDig[:,-1] == 2)[0]
# MCI shape after separting it from two other lables
print(NMCI.shape)
# AD shape after separting it from two other lables
AD = np.where(CombinedFeatDig[:,-1] == 3)[0]
print(AD.shape)
# Out:
# (235,)
# (215,)
# (250,)

# %%
# # save the model
# dump(model, open('model.pkl', 'wb'))
# # save the scaler
# dump(scaler, open('scaler.pkl', 'wb'))

# %%
# Creating x and Y for each classes
NC_data_x = CombinedFeatDig[:,0:16000][NC]
NC_data_y = CombinedFeatDig[:,-1][NC]
print("-"*60)
print("Normal Control shape:",NC_data_x.shape)
print("Normal Control lable shape:",NC_data_y.shape)


NMCI_data_x =CombinedFeatDig[:,0:16000][NMCI]
NMCI_data_y = CombinedFeatDig[:,-1][NMCI]
print("-"*60)
print("NMCI shape:",NMCI_data_x.shape)
print("NMCI Y label:",NMCI_data_y.shape)

AD_data_x = CombinedFeatDig[:,0:16000][AD]
AD_data_y = CombinedFeatDig[:,-1][AD]
print("-"*60)
print("Alzheimer Disease shape :",AD_data_x.shape)
print("Alzheimer Disease Y label shape :",AD_data_y.shape)
# Out:
# ------------------------------------------------------------
# Normal Control shape: (235, 16000)
# Normal Control lable shape: (235,)
# ------------------------------------------------------------
# NMCI shape: (215, 16000)
# NMCI Y label: (215,)
# ------------------------------------------------------------
# Alzheimer Disease shape : (250, 16000)
# Alzheimer Disease Y label shape : (250,)

# %%
from pickle import dump
# save the NC data
dump(NC_data_x, open('NC_data_x.pkl', 'wb'))
# save the scaler
dump(NC_data_y, open('NC_data_y.pkl', 'wb'))

# save the MCI data
dump(NMCI_data_x, open('MCI_data_x.pkl', 'wb'))
# save the scaler
dump(NMCI_data_y, open('MCI_data_y.pkl', 'wb'))

# save the AD data
dump(AD_data_x, open('AD_data_x.pkl', 'wb'))

dump(AD_data_y, open('AD_data_y.pkl', 'wb'))

# %%
from pickle import load
# load the NC data
NC_data_x = load(open('NC_data_x.pkl', 'rb'))
# load the NC_y data
NC_data_y= load(open('NC_data_y.pkl', 'rb'))

# load the AD_X data
AD_data_x = load(open('AD_data_x.pkl', 'rb'))
# load the AD_y data
AD_data_y= load(open('AD_data_y.pkl', 'rb'))

# %% [markdown]
# # AD vs Normal Control Training

# %%
# combining Ad vs Normal for classification
ADvsNC_X=np.concatenate((AD_data_x, NC_data_x), axis=0)
print(ADvsNC_X.shape)

ADvsNC_Y=np.concatenate((AD_data_y, NC_data_y), axis=0)
print(ADvsNC_Y.shape)
# Out:
# (485, 16000)
# (485,)

# %%
# combining Ad vs Normal for classification
ADvsNC_X=np.concatenate((AD_data_x, NC_data_x), axis=0)
print(ADvsNC_X.shape)

ADvsNC_Y=np.concatenate((AD_data_y, NC_data_y), axis=0)
print(ADvsNC_Y.shape)
# Out:
# (485, 16000)
# (485,)

# %%
# changing ad=1 and nc=0
where_3 = np.where(ADvsNC_Y== 3)
where_1 = np.where(ADvsNC_Y == 1)

ADvsNC_Y[where_3] = 1
ADvsNC_Y[where_1] = 0
ADvsNC_Y.shape
# Out:
# (485,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNC_X, ADvsNC_Y, test_size=0.20, random_state=123)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.10, random_state=123)

# %%
print("Alzheimer's diseas and Normal Train shape :",X_train.shape)
# print("Alzheimer's diseas and Normal Validation shape :",X_val.shape)
print("Alzheimer's diseas and Normal Test shape :",X_test.shape)
# Out:
# Alzheimer's diseas and Normal Train shape : (388, 16000)
# Alzheimer's diseas and Normal Test shape : (97, 16000)

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# Aplying Scaling so that all features be on the same scale.
scaler = MinMaxScaler(feature_range = (0, 1))
scaler.fit(X_train)
X_train=scaler.transform(X_train)
# scaler.fit(X_val)
# X_val=scaler.transform(X_val)
X_test=scaler.transform(X_test)
scaler.fit(X_test)
print("Alzheimer's diseas and Normal Train shape :",X_train.shape)
# print("Alzheimer's diseas and Normal Validation shape :",X_val.shape)
print("Alzheimer's diseas and Normal Test shape :",X_test.shape)
print("Std of test set : ", np.std(X_test))
print("Mean of test set: ",np.mean(X_test))
# Out:
# Alzheimer's diseas and Normal Train shape : (388, 16000)
# Alzheimer's diseas and Normal Test shape : (97, 16000)
# Std of test set :  0.19619350263237
# Mean of test set:  0.36680609437408246

# %%
# %%time
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, log_loss
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import roc_auc_score

classifiers = [
    SVC(random_state=25),
    DecisionTreeClassifier(random_state=25),
    RandomForestClassifier(random_state=25),
    XGBClassifier(random_state=25),
    ]



models_cols=["Classifiers", "Accuracy","F1_score_NC", "F1_score_AD"]
models_df = pd.DataFrame(columns=models_cols)

for models in classifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train)
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    f1_scores1 = f1_score(y_test.ravel(), train_predictions,pos_label=0)
    f1_scores2 = f1_score(y_test.ravel(), train_predictions,pos_label=1)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NC: {:.2%}".format(f1_scores1))
    print("F1_Score of AD: {:.2%}".format(f1_scores2))
    models_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100]], columns=models_cols)
    models_df = models_df.append(models_entry)
    
    
    
print("="*30)
# Out:
# ==============================
# SVC
# ****Results****
# Training 92.78%
# Accuracy 82.47%
# F1_Score of NC: 80.90%
# F1_Score of AD: 83.81%
# ==============================
# DecisionTreeClassifier
# ****Results****
# Training 100.00%
# Accuracy 56.70%
# F1_Score of NC: 53.33%
# F1_Score of AD: 59.62%
# ==============================
# RandomForestClassifier
# ****Results****
# Training 100.00%
# Accuracy 76.29%
# F1_Score of NC: 75.27%
# F1_Score of AD: 77.23%
# [11:59:16] WARNING: /Users/travis/build/dmlc/xgboost/src/learner.cc:1095: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ==============================
# XGBClassifier
# ****Results****
# Training 100.00%
# Accuracy 71.13%
# F1_Score of NC: 69.57%
# F1_Score of AD: 72.55%
# ==============================
# CPU times: user 1min 20s, sys: 3.15 s, total: 1min 23s
# Wall time: 24.2 s

# %%
from sklearn.metrics import plot_roc_curve
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,10))    
ax = plt.gca()
for i in classifiers:
    plot_roc_curve(i, X_test, y_test, ax=ax)
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of AD vs Normal Control Before PCA of NC vs AD')
# Out:
# Text(0.5, 1.0, 'AUC score of AD vs Normal Control Before PCA of NC vs AD')

# %%
import pandas as pd
from sklearn.decomposition import PCA

def set_custom_palette(series, max_color = 'crimson', other_color = 'b'):
    max_val = series.max()
    pal = []
    
    for item in series:
        if item == max_val:
            pal.append(max_color)
        else:
            pal.append(other_color)
    return pal

sns.set_color_codes("dark")
clrs=set_custom_palette(models_df['Accuracy'])
sns.barplot(x='Accuracy', y='Classifiers', data=models_df,palette=clrs, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy before PCA of NC vs AD')
plt.show()

# %%
# plotting F1_score before applying 

sns.set_color_codes("dark")
clrs=set_custom_palette(models_df['F1_score_NC'],other_color = 'g')
sns.barplot(x='F1_score_NC', y='Classifiers', data=models_df,palette=clrs, color="g")

plt.xlabel('F1-Score %')
plt.title('Normal F1-Score')
plt.show()

sns.set_color_codes("muted")
clrs=set_custom_palette(models_df['F1_score_AD'],other_color = 'r')
sns.barplot(x='F1_score_AD', y='Classifiers', data=models_df,palette=clrs, color="r")

plt.xlabel('F1-Score %')
plt.title('Alzheimer Disease F1-Score')
plt.show()

# %%
pca_test = PCA(n_components=250)
pca_test.fit(X_train)
# sns.set(style='whitegrid')
plt.style.use('fivethirtyeight')
plt.plot(np.cumsum(pca_test.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.axvline(linewidth=4, color='r', linestyle = '--', x=150, ymin=0, ymax=1)
display(plt.show())
evr = pca_test.explained_variance_ratio_
cvr = np.cumsum(pca_test.explained_variance_ratio_)
pca_df = pd.DataFrame()
pca_df['Cumulative Variance Ratio'] = cvr
pca_df['Explained Variance Ratio'] = evr
display(pca_df.head(150))
# Out:
# None
#      Cumulative Variance Ratio  Explained Variance Ratio
# 0                     0.153562                  0.153562
# 1                     0.191197                  0.037635
# 2                     0.225231                  0.034034
# 3                     0.249309                  0.024079
# 4                     0.270882                  0.021573
# ..                         ...                       ...
# 145                   0.853329                  0.001269
# 146                   0.854586                  0.001257
# 147                   0.855838                  0.001252
# 148                   0.857086                  0.001248
# 149                   0.858330                  0.001244
#
# [150 rows x 2 columns]

# %%
from math import sqrt
pca=PCA(150)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
var_exp = pca.explained_variance_ratio_
X_val_pca=pca.transform(X_val)
X_test_pca = pca.transform(X_test)
print("Total variance explianed by 250 components:", var_exp.sum())
print("std of test set AFTER PCA: ", np.std(X_test_pca))
print("mean of test set AFTER PCA: ",np.mean(X_test_pca))
print("std of test set BEFORE PCA:: ", np.std(X_test))
print("mean of test set BEFORE PCA: ",np.mean(X_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-86ffde5aa14a> in <module>
#       4 X_train_pca = pca.transform(X_train)
#       5 var_exp = pca.explained_variance_ratio_
# ----> 6 X_val_pca=pca.transform(X_val)
#       7 X_test_pca = pca.transform(X_test)
#       8 print("Total variance explianed by 250 components:", var_exp.sum())
#
# NameError: name 'X_val' is not defined

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
# Aplying Scaling so that all features be on the same scale.
scaler = MinMaxScaler(feature_range = (0, 1))
scaler.fit(X_train_pca)
X_train=scaler.transform(X_train_pca)
scaler.fit(X_val)
X_val=scaler.transform(X_val)
X_test=scaler.transform(X_test_pca)
scaler.fit(X_test_pca)
print("Alzheimer's diseas and Normal Train shape :",X_train.shape)
# print("Alzheimer's diseas and Normal Validation shape :",X_val.shape)
print("Alzheimer's diseas and Normal Test shape :",X_test.shape)
print("Std of test set : ", np.std(X_test))
print("Mean of test set: ",np.mean(X_test))

# %%
models_cols=["Classifiers", "Accuracy","F1_score_NC", "F1_score_AD"]
models_df = pd.DataFrame(columns=models_cols)

for models in classifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train)
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    f1_scores1 = f1_score(y_test.ravel(), train_predictions,pos_label=0)
    f1_scores2 = f1_score(y_test.ravel(), train_predictions,pos_label=1)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NC: {:.2%}".format(f1_scores1))
    print("F1_Score of AD: {:.2%}".format(f1_scores2))
    models_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100]], columns=models_cols)
    models_df = models_df.append(models_entry)
    
    
    
print("="*30)

# %%
models_cols=["Classifiers", "Accuracy","F1_score_NC", "F1_score_AD"]
models_df = pd.DataFrame(columns=models_cols)

for models in classifiers:
    models.fit(X_train_pca, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test_pca)
    trainingscore=models.score(X_train_pca, y_train)
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    f1_scores1 = f1_score(y_test.ravel(), train_predictions,pos_label=0)
    f1_scores2 = f1_score(y_test.ravel(), train_predictions,pos_label=1)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NC: {:.2%}".format(f1_scores1))
    print("F1_Score of AD: {:.2%}".format(f1_scores2))
    models_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100]], columns=models_cols)
    models_df = models_df.append(models_entry)
    
    
    
print("="*30)

# %%
plt.style.use('fivethirtyeight')
# classifiers = [clf_svm, clf_dtc, rfc,clf]
plt.figure(figsize=(10,10))    
ax = plt.gca()
for i in classifiers:
    plot_roc_curve(i, X_test, y_test, ax=ax)
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of AD vs Normal Control AFTER PCA of NC vs AD.')

# %%
plt.style.use('fivethirtyeight')
# classifiers = [clf_svm, clf_dtc, rfc,clf]
plt.figure(figsize=(10,10))    
ax = plt.gca()
for i in classifiers:
    plot_roc_curve(i, X_test_pca, y_test, ax=ax)
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of AD vs Normal Control AFTER PCA of NC vs AD.')

# %%
sns.set_color_codes("dark")
clrs=set_custom_palette(models_df['Accuracy'])
sns.barplot(x='Accuracy', y='Classifiers', data=models_df,palette=clrs, color="b")

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy AFTER PCA of NC vs AD')
plt.show()

# %%
sns.set_color_codes("dark")
clrs=set_custom_palette(models_df['F1_score_NC'],other_color = 'g')
sns.barplot(x='F1_score_NC', y='Classifiers', data=models_df,palette=clrs, color="g")

plt.xlabel('F1-Score %')
plt.title('Normal F1-Score')
plt.show()

sns.set_color_codes("muted")
clrs=set_custom_palette(models_df['F1_score_AD'],other_color = 'r')
sns.barplot(x='F1_score_AD', y='Classifiers', data=models_df,palette=clrs, color="r")

plt.xlabel('F1-Score %')
plt.title('Alzheimer Disease F1-Score')
plt.show()

# %% [markdown]
# # AD Vs Normal Control HYPERPARAMTER TUNNING

# %% [markdown]
# ## SVM HYPERPARAMTER TUNNING

# %%
# %%time

from sklearn.model_selection import PredefinedSplit,GridSearchCV
# PredefinedSplit
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV 
from sklearn.svm import SVC as svc 
from sklearn.metrics import make_scorer, roc_auc_score
from scipy import stats


# Save mean cross-validated accuracy scores of best models
cross_valid_scores = {}
best_estimator_Score={}

parameters = {
    "C": [0.001, 0.01, 0.1, 1.0,1.4,1.5,2.0,2.4,3.0],
    "kernel": ["linear", "poly", "sigmoid","rbf"],
    "gamma": ["scale", "auto"],
#      "class_weight":["balanced",None],
    "probability":[True,False]
}

model_svc = SVC(
    random_state=25,
#     class_weight="balanced",
    
    
)

 

model_svc = GridSearchCV(
    model_svc, 
    parameters, 
    cv=5,
    scoring='accuracy',
    return_train_score=True,
)


model_svc.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_svc.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + 
    f'{model_svc.best_score_:.3f}'
       
)
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_svc.best_estimator_.score( X_test_pca, y_test.ravel()))

    
cross_valid_scores['SVM Model'] = model_svc.best_score_
best_estimator_Score['SVM Model']=model_svc.best_estimator_.score( X_test_pca, y_test.ravel())
print('-----')

# %%
# %%time

from sklearn.model_selection import PredefinedSplit,GridSearchCV
# PredefinedSplit
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV 
from sklearn.svm import SVC as svc 
from sklearn.metrics import make_scorer, roc_auc_score
from scipy import stats


# Save mean cross-validated accuracy scores of best models
cross_valid_scores = {}
best_estimator_Score={}

parameters = {
    "C": [0.001, 0.01, 0.1, 1.0,1.4,1.5,2.0,2.4,3.0],
    "kernel": ["linear", "poly", "sigmoid","rbf"],
    "gamma": ["scale", "auto"],
#      "class_weight":["balanced",None],
    "probability":[True,False]
}

model_svc = SVC(
    random_state=25,
#     class_weight="balanced",
    
    
)

 

model_svc = GridSearchCV(
    model_svc, 
    parameters, 
    cv=5,
    scoring='accuracy',
    return_train_score=True,
)


model_svc.fit(X_train, y_train.ravel())

print('-----')
print(f'Best parameters {model_svc.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + 
    f'{model_svc.best_score_:.3f}'
       
)
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_svc.best_estimator_.score( X_test, y_test.ravel()))

    
cross_valid_scores['SVM Model'] = model_svc.best_score_
best_estimator_Score['SVM Model']=model_svc.best_estimator_.score( X_test, y_test.ravel())
print('-----')

# %% [markdown]
# ## Desicion Tree HYPERPARAMTER TUNNING

# %%
# %%time
parameters = {
    "criterion":["gini","entropy"],
    "max_depth":range(1,20),
    "min_samples_split":range(0,10),
#     "class_weight":["balanced",None],
    "min_samples_leaf":range(1,10)                   
}




model_desicion_tree = DecisionTreeClassifier(
    random_state=25
)

model_desicion_tree = GridSearchCV(
    model_desicion_tree, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_desicion_tree.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_desicion_tree.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + \
    f'{model_desicion_tree.best_score_:.3f}'
)
# using validation set to test the best estimator
# print('Best estimator score on Validation set : %.3f'%model_desicion_tree.best_estimator_.score( X_val_pca, y_val))
# cross_valid_scores['Desicion_Tree Model'] = model_desicion_tree.best_score_

# best_estimator_Score['Desicion_Tree Model']=model_desicion_tree.best_estimator_.score( X_val_pca, y_val)
print('-----')

print('Best estimator score on Validation set : %.3f'%model_desicion_tree.best_estimator_.score( X_test_pca, y_test.ravel()))

    
cross_valid_scores['SVM Model'] = model_desicion_tree.best_score_
best_estimator_Score['SVM Model']=model_desicion_tree.best_estimator_.score( X_test_pca, y_test.ravel())
print('-----')

# %%
# %%time
parameters = {
    "criterion":["gini","entropy"],
    "max_depth":range(1,20),
    "min_samples_split":range(0,10),
#     "class_weight":["balanced",None],
    "min_samples_leaf":range(1,10)                   
}




model_desicion_tree = DecisionTreeClassifier(
    random_state=25
)

model_desicion_tree = GridSearchCV(
    model_desicion_tree, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_desicion_tree.fit(X_train, y_train.ravel())

print('-----')
print(f'Best parameters {model_desicion_tree.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + \
    f'{model_desicion_tree.best_score_:.3f}'
)
# using validation set to test the best estimator
# print('Best estimator score on Validation set : %.3f'%model_desicion_tree.best_estimator_.score( X_val_pca, y_val))
# cross_valid_scores['Desicion_Tree Model'] = model_desicion_tree.best_score_

# best_estimator_Score['Desicion_Tree Model']=model_desicion_tree.best_estimator_.score( X_val_pca, y_val)
print('-----')

print('Best estimator score on Validation set : %.3f'%model_desicion_tree.best_estimator_.score( X_test, y_test.ravel()))

    
cross_valid_scores['SVM Model'] = model_desicion_tree.best_score_
best_estimator_Score['SVM Model']=model_desicion_tree.best_estimator_.score( X_test, y_test.ravel())
print('-----')

# %% [markdown]
# # Random Forest HYPERPARAMTERER TUNNING

# %%
import numpy as np 
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_val_score

random_search = {'criterion': ['entropy', 'gini'],
               'max_depth': list(np.linspace(10, 1200, 10, dtype = int)) + [None],
               'max_features': ['auto', 'sqrt','log2', None],
               'min_samples_leaf': [4, 6, 8, 12],
               'min_samples_split': [5, 7, 10, 14],
               'n_estimators': list(np.linspace(151, 1200, 10, dtype = int))}

clf = RandomForestClassifier()
model = RandomizedSearchCV(estimator = clf, param_distributions = random_search, n_iter = 80, 
                               cv = 5, verbose= 5, random_state= 101, n_jobs = -1)
model.fit(X_train_pca, y_train.ravel())

# %%
predictionforest = model.best_estimator_.predict(X_test_pca)
model.best_estimator_.score( X_test_pca, y_test.ravel())
model.best_params_

# %%
# %%time

# parameters = {
#     "criterion":["gini","entropy"],
#     "n_estimators": [5, 50,100,500], 
#     "max_features":range(5,11),
# #     "bootstrap":[True,False],
#     "class_weight":["balanced",None],
#     "min_samples_split":range(1,10),
#     "max_depth": [3,20,50,100,460],
    
# }
parameters = {
    "n_estimators": [5, 10, 15, 20, 25], 
    "max_features":range(5,11),
    "bootstrap":[True,False],
    "max_depth": [3, 5, 7, 9, 11, 13],
    
}
model_random_forest = RandomForestClassifier(
    random_state=25,
    class_weight='balanced',
)

model_random_forest = GridSearchCV(
    model_random_forest, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_random_forest.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_random_forest.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: '+ \
    f'{model_random_forest.best_score_:.3f}'
)


print('Best estimator score on Validation set : %.3f'%model_desicion_tree.best_estimator_.score( X_test_pca, y_test.ravel()))

    
cross_valid_scores['SVM Model'] = model_random_forest.best_score_
best_estimator_Score['SVM Model']=model_random_forest.best_estimator_.score( X_test_pca, y_test.ravel())
print('-----')
# cross_valid_scores['Random_Forest'] = model_random_forest.best_score_

# # using validation set to test the best estimator
# print('Best estimator score on Validation set : %.3f'%model_random_forest.best_estimator_.score(X_val_pca, y_val))

# best_estimator_Score['Random Forest Model']=model_random_forest.best_estimator_.score(X_val_pca, y_val)
# print('-----')

# model_desicion_tree

# %% [markdown]
# # XGBOOST HYPERPARAMETER TUNNING

# %%
# %%time
parameters = {
    'max_depth': [3, 5, 7, 9], 
    'n_estimators': [5, 10, 15, 20, 25, 50, 100],
    'learning_rate': [0.01, 0.05, 0.1],
    
}

model_xgb = XGBClassifier(
    random_state=25,
)

model_xgb = GridSearchCV(
    model_xgb, 
    parameters, 
    cv=5,
    scoring='accuracy',
     # add this line to slient warning message
)

model_xgb.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_xgb.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + 
    f'{model_xgb.best_score_:.3f}'
)
cross_valid_scores['XGBOOST Model'] = model_xgb.best_score_

# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_xgb.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['XG-Boost Model']=model_xgb.best_estimator_.score(X_val_pca, y_val)
print('-----')

# %%
pd.DataFrame(cross_valid_scores, index=['Best Accuracy Through Grid Search ']).T

# %%
pd.DataFrame(best_estimator_Score, index=['Best Estimator Score on Validation Set']).T

# %% [markdown]
# ## Applying Best Paramaters for each models after Hyper Paramater tunning.

# %%
# combining Training and validation set which makes training set 80% and  test set 20%
X_train_pca=np.concatenate((X_val_pca, X_train_pca), axis=0)
y_train=np.concatenate((y_val, y_train), axis=0)
print(X_train_pca.shape)
print(y_train.shape)
print(X_test_pca.shape)

# %%
# Create the final SVM Classifier

# svc classifier with best parameter 
# Best parameters {'C': 1.0, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'sigmoid', 'probability': True}
# Mean cross-validated accuracy score of the best_estimator: 0.817
svc_final = SVC(
    
    random_state=25,
    probability=True,
    C= 1.4, 
    gamma= 'scale',
    kernel= 'sigmoid'
)


# Best parameters {'class_weight': None, 'criterion': 'entropy', 'max_depth': 5, 'max_features': 10, 'n_estimators': 20}
# Create the final Random Forest
rf_final = RandomForestClassifier(
            random_state=25,
            criterion='entropy',
            class_weight='balanced',
            bootstrap=False,
            max_depth=13,
            max_features=8,
            n_estimators= 25
)


# Best parameters {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 2, 'min_samples_split': 6}

# Create the final Random Forest
dt_final = DecisionTreeClassifier(
            criterion='entropy',
            max_depth=4,
            min_samples_leaf=1,
            min_samples_split=2,
            random_state=25
)


# Create the fnal Extreme Gradient Booster
xgb_final = XGBClassifier(
        learning_rate=0.1, 
        max_depth=9, 
        n_estimators= 25,
        random_state=25,
       
       
)

# %%
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.metrics import roc_auc_score
# classfiers obtained from hyperparatmeter with tehe ebst parameters
finalClassifiers = [svc_final, rf_final, dt_final,xgb_final]
# craeting new df to save the result of traning and testing
final_cols=["Classifier", "Accuracy","F1_score_NC", "F1_score_AD","Sensitivity_Score","Specificity_Score","AUC"]
final = pd.DataFrame(columns=final_cols)
# for loop that iterates over each name, model in models list
for models in finalClassifiers:
    models.fit(X_train_pca, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test_pca)
    trainingscore=models.score(X_train_pca, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    f1_scores1 = f1_score(y_test.ravel(), train_predictions,pos_label=0)
    f1_scores2 = f1_score(y_test.ravel(), train_predictions,pos_label=1)
#     computing sensitivity,specificity from consuion matrix
    confusion=confusion_matrix(y_test.ravel(), train_predictions)
#     getting TN from row 0 and column 0
    TN = confusion[0][0]
#     getting FN from row 1 and column 0
    FN = confusion[1][0]
#     getting TP from row 1 and column 1
    TP = confusion[1][1]
#     getting FP from row 0 and column 1
    FP = confusion[0][1]
#    sensitivity computed from TP divided by (False negative + True postive) 
    sens=TP/(FN+TP)
#     specificity computed from TN divided by(True neagtive + False postive)
    spec=TN/(TN+FP)
#     predict probability for computing AUC
    predic = models.predict_proba(X_test_pca)[:, 1]

#     AUC Score
    auc = roc_auc_score(y_test.ravel(), predic)

    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NC: {:.2%}".format(f1_scores1))
    print("F1_Score of AD: {:.2%}".format(f1_scores2))
    print("Sensitivity Score: {:.2%}".format(sens))
    print("Specificity Score: {:.2%}".format(spec))
    print("AUC Score: {:.2%}".format(auc))

    final_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100,sens,spec,auc]], columns=final_cols)
    final = final.append(final_entry )
    
print("="*30)

# %%
plt.style.use('fivethirtyeight')
# plotting Auc curve for Ad vs Normal control by using plot_roc_curve from sklearn libarary 
plt.figure(figsize=(10,10))    
ax = plt.gca()
# loop through classifiers and plot auc curve for each model
for i in finalClassifiers:
    plot_roc_curve(i, X_test_pca, y_test, ax=ax)
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of AD vs Normal Control AFTER Hyper-Parameter Tunning of NC vs AD')

# %%
# bar plot for teh accuarcy of ecah classifiers
sns.set_color_codes("dark")
clrs=set_custom_palette(final['Accuracy'],max_color = 'crimson', other_color = 'b')
sns.barplot(x='Accuracy', y='Classifier', data=final, palette=clrs,color="b",)

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy After Hyper parameter tunning of NC vs AD ')
plt.show()

# %%
# Declaring the figure or the plot (y, x) or (width, height)
plt.figure(figsize=[10, 10])
# Data to be plotted
f1_nc = final["F1_score_NC"]
f1_ad = final["F1_score_AD"]

# Using numpy to group 3 different data with bars
X = np.arange(len(f1_nc))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
# changing color to dark khaki if it has highest value for f-score-nc
clrs = ["khaki" if (x < max(f1_nc)) else 'darkkhaki' for x in f1_nc ]
plt.barh(X, f1_nc, color = clrs, height = 0.25)
# changing color to dark salmon if it has highest value for f-score-ad
clrs = ["salmon" if (x < max(f1_ad)) else 'darksalmon' for x in f1_ad]
plt.barh(X + 0.25, f1_ad, color = clrs, height = 0.25)

# Creating the legend of the bars in the plot
plt.legend(['F1_score_NC', 'F1_score_AD'])

plt.yticks([i + 0.25 for i in range(4)], ["SVC","RandomForestClassifier","DecisionTreeClassifier","XGBClassifier"])
# Giving the tilte for the plot
plt.title("Bar plot of F1_score in AD vs NC")
# Namimg the x and y axis
plt.ylabel('Classifiers')
plt.xlabel('Scores')

plt.show()

# %%
# Declaring the figure or the plot (y, x) or (width, height)
plt.figure(figsize=[10, 10])
# Data to be plotted
sensi = final["Sensitivity_Score"]
speci = final["Specificity_Score"]

# Using numpy to group 3 different data with bars
X = np.arange(len(sensi))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
clrs = ['cadetblue' if (x < max(sensi)) else 'mediumseagreen' for x in sensi ]
plt.barh(X, sensi, color = clrs, height = 0.25)
clrs = ['thistle' if (x < max(speci)) else 'violet' for x in speci ]
plt.barh(X + 0.25, speci, color = clrs, height = 0.25)

# Creating the legend of the bars in the plot
plt.legend(['Sensitivity_Score', 'Specificity_Score'])

plt.yticks([i + 0.25 for i in range(4)], ["SVC","RandomForestClassifier","DecisionTreeClassifier","XGBClassifier"])
# Giving the tilte for the plot
plt.title("Bar plot of Sensitivity and Specificity in AD vs NC")
# Naming the x and y axis
plt.ylabel('Classifiers')
plt.xlabel('Scores')

plt.show()

# %% [markdown]
# #   Normal Control vs MCI

# %%
# In order to perofm classification on NC and MCI these two data set are concatenated.
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
where_1 = np.where(NCvsNMCI_Y== 1)
where_2 = np.where(NCvsNMCI_Y== 2)

NCvsNMCI_Y[where_1] = 0
NCvsNMCI_Y[where_2] = 1
NCvsNMCI_Y.shape

# %%
from sklearn.model_selection import train_test_split
# splitting the above data into training,testing and validation sets
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X, NCvsNMCI_Y, test_size=0.20, random_state=123)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.10, random_state=123)

# %%
# looking at the shape of each sets.
print("Training Set shape:",X_train.shape)
print("Validation Set shape:",X_val.shape)
print("Test Set shape:",X_test.shape)

# %%
# peefoming MinMAx sacaler so that all features be on the same scale.
scaler = MinMaxScaler(feature_range = (0, 1))
scaler.fit(X_train)
X_train=scaler.transform(X_train)
scaler.fit(X_val)
X_val=scaler.transform(X_val)
X_test=scaler.transform(X_test)
scaler.fit(X_test)
print("Alzheimer's diseas and Normal Train shape :",X_train.shape)
print("Alzheimer's diseas and Normal Validation shape :",X_val.shape)
print("Alzheimer's diseas and Normal Test shape :",X_test.shape)

# %%
# looking at teh tarning and validations core of four models before applying PCA
models_cols=["Classifiers", "Accuracy","F1_score_NM", "F1_score_NMCI"]
models_df = pd.DataFrame(columns=models_cols)

for models in classifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_val)
    trainingscore=models.score(X_train, y_train)
    accuracy = accuracy_score(y_val.ravel(), train_predictions)
    f1_scores1 = f1_score(y_val.ravel(), train_predictions,pos_label=0)
    f1_scores2 = f1_score(y_val.ravel(), train_predictions,pos_label=1)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NM: {:.2%}".format(f1_scores1))
    print("F1_Score of NMCI: {:.2%}".format(f1_scores2))
    models_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100]], columns=models_cols)
    models_df = models_df.append(models_entry)
    
    
    
print("="*30)

# %%
sns.set_color_codes("pastel")
clrs=set_custom_palette(models_df['Accuracy'],max_color = 'red', other_color = 'g')
sns.barplot(x='Accuracy', y='Classifiers', data=models_df, palette=clrs,color="g",)

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy Before PCA ')
plt.show()

# %%
# Redcuicng dimensionality of teh data from 16000 to 150d.
pca=PCA(150)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
var_exp = pca.explained_variance_ratio_
X_val_pca=pca.transform(X_val)
X_test_pca = pca.transform(X_test)
print("Total variance explianed by 150 components:", var_exp.sum())

# %%
# comparing the perfrmance of the models after perfroming PCA.

models_cols=["Classifiers", "Accuracy","F1_score_NM", "F1_score_NMCI"]
models_df = pd.DataFrame(columns=models_cols)

for models in classifiers:
    models.fit(X_train_pca, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test_pca)
    trainingscore=models.score(X_train_pca, y_train)
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    f1_scores1 = f1_score(y_test.ravel(), train_predictions,pos_label=0)
    f1_scores2 = f1_score(y_test.ravel(), train_predictions,pos_label=1)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NC: {:.2%}".format(f1_scores1))
    print("F1_Score of MCI: {:.2%}".format(f1_scores2))
    models_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100]], columns=models_cols)
    models_df = models_df.append(models_entry)
    
    
    
print("="*30)

# %%
# plotting the above results.
sns.set_color_codes("pastel")
clrs=set_custom_palette(models_df['Accuracy'],max_color = 'red', other_color = 'g')
sns.barplot(x='Accuracy', y='Classifiers', data=models_df, palette=clrs,color="g",)

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy AFTER PCA ')
plt.show()

# %% [markdown]
# # Normal Control vs NMCI HYPERPARAMTER TUNNING

# %% [markdown]
# ## SVM HYPERPARAMTER TUNNING

# %%
# %%time


# SVm hyperparameter tunning by trying difefrent values.
cross_valid_scores = {}
best_estimator_Score={}
parameters = {
    "C": [0.001, 0.01, 0.1, 2,3,4],
    "kernel": ["linear", "poly", "rbf", "sigmoid"],
    "gamma": ["scale", "auto"],
}

model_svc = SVC(
    random_state=25,
    class_weight="balanced",
    probability=True,
)

model_svc = GridSearchCV(
    model_svc, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_svc.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_svc.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + 
    f'{model_svc.best_score_:.3f}'
)
cross_valid_scores['svc'] = model_svc.best_score_
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_svc.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['XG-Boost Model']=model_svc.best_estimator_.score(X_val_pca, y_val)
print('-----')

# %% [markdown]
# ## Desicion Tree HYPERPARAMTER TUNNING

# %%
# %%time
parameters = {
    "criterion":["gini","entropy"],
    "max_depth":range(1,20),
    "min_samples_split":range(2,10),
    "min_samples_leaf":range(1,5)
                      
}


model_desicion_tree = DecisionTreeClassifier(
    random_state=25
)

model_desicion_tree = GridSearchCV(
    model_desicion_tree, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_desicion_tree.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_desicion_tree.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + \
    f'{model_desicion_tree.best_score_:.3f}'
)
cross_valid_scores['desicion_tree'] = model_desicion_tree.best_score_

# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_desicion_tree.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['XG-Boost Model']=model_desicion_tree.best_estimator_.score(X_val_pca, y_val)

print('-----')

# %% [markdown]
# #  Random Forest HYPERPARAMTERER TUNNING

# %%
# %%time


parameters = {
    "criterion":["gini","entropy"],
    "n_estimators": [5, 10, 15, 20, 25], 
    "max_features":range(5,11),
    "bootstrap":[True,False],
    "class_weight":["balanced",None],
    "max_depth": [3, 5, 7, 9, 11, 13,None],
    
}



model_random_forest = RandomForestClassifier(
    random_state=25,
    class_weight='balanced',
)

model_random_forest = GridSearchCV(
    model_random_forest, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_random_forest.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_random_forest.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: '+ \
    f'{model_random_forest.best_score_:.3f}'
)
cross_valid_scores['random_forest'] = model_random_forest.best_score_
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_random_forest.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['XG-Boost Model']=model_random_forest.best_estimator_.score(X_val_pca, y_val)

print('-----')

# %% [markdown]
# #  XGBOOST HYPERPARAMETER TUNNING

# %%
# %%time
parameters = {
    'max_depth': [3, 5, 7, 9], 
    'n_estimators': [5, 10, 15, 20, 25, 50, 100],
    'learning_rate': [0.01, 0.05, 0.1],
    'verbosity': [0]
}

model_xgb = XGBClassifier(
    random_state=25,
)

model_xgb = GridSearchCV(
    model_xgb, 
    parameters, 
    cv=5,
    scoring='accuracy',
     # add this line to slient warning message
)

model_xgb.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_xgb.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + 
    f'{model_xgb.best_score_:.3f}'
)
cross_valid_scores['xgboost'] = model_xgb.best_score_
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_xgb.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['XG-Boost Model']=model_xgb.best_estimator_.score(X_val_pca, y_val)

print('-----')

# %%
pd.DataFrame(cross_valid_scores, index=['Best Accuracy Through Grid Search']).T

# %%
pd.DataFrame(best_estimator_Score, index=['Best estimator score on Validation set']).T

# %% [markdown]
# ## Applying Best Paramaters for each models after Hyper Paramater tunning.

# %%
# Applying Best Paramaters for each models after Hyper Paramater tunning

finalClassifiers=[]
svc_final = SVC(
    random_state=25,
    probability=True,
    C= 1 ,
    gamma= 'scale',
    kernel= "sigmoid"
)


rf_final = RandomForestClassifier(
            random_state=25,
            class_weight='balanced',
            bootstrap=True,
            max_depth=13,
            max_features=6,
            n_estimators= 25
)


dt_final = DecisionTreeClassifier(
            criterion='entropy',
            max_depth=8,
            min_samples_leaf=2,
            min_samples_split=2,
            random_state=25
)


# Create the fnal Extreme Gradient Booster
xgb_final = XGBClassifier(
        learning_rate=0.1, 
        max_depth=7, 
        n_estimators= 100,
        random_state=25,
        verbosity= 0,
       
)

# %%
# comapring the metrics after trying the best parameters for each classifiers.

finalClassifiers = [svc_final, rf_final, dt_final,xgb_final]
final_cols=["Classifier", "Accuracy","F1_score_NC", "F1_score_NMCI","Sensitivity_Score","Specificity_Score","AUC"]
final = pd.DataFrame(columns=final_cols)

for models in finalClassifiers:
    models.fit(X_train_pca, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test_pca)
    trainingscore=models.score(X_train_pca, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    f1_scores1 = f1_score(y_test.ravel(), train_predictions,pos_label=0)
    f1_scores2 = f1_score(y_test.ravel(), train_predictions,pos_label=1)
#     computing sensitivity,specificity from consuion matrix
    confusion=confusion_matrix(y_test.ravel(), train_predictions)
#     getting TN from row 0 and column 0
    TN = confusion[0][0]
#     getting FN from row 1 and column 0
    FN = confusion[1][0]
#     getting TP from row 1 and column 1
    TP = confusion[1][1]
#     getting FP from row 0 and column 1
    FP = confusion[0][1]
#    sensitivity computed from TP divided by (False negative + True postive) 
    sens=TP/(FN+TP)
#     specificity computed from TN divided by(True neagtive + False postive)
    spec=TN/(TN+FP)
    
    predic = models.predict_proba(X_test_pca)[:, 1]

#     AUC Score
    auc = roc_auc_score(y_test.ravel(), predic)
  
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NC: {:.2%}".format(f1_scores1))
    print("F1_Score of MCI: {:.2%}".format(f1_scores2))
    print("Sensitivity Score: {:.2%}".format(sens))
    print("Specificity Score: {:.2%}".format(spec))
    print("AUC Score: {:.2%}".format(auc))

    final_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100,sens*100,spec*100,auc*100]], columns=final_cols)
    final = final.append(final_entry )
print("="*30)

# %%
final

# %%
# plotting AUC curvee 
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,10))    
ax = plt.gca()
for i in finalClassifiers:
    plot_roc_curve(i, X_test_pca, y_test, ax=ax)
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of Normal Control vs MCI "AFTER" Hyper-Parameter Tunning.')

# %%
# plotting the accuarcy score of different models

sns.set_color_codes("deep")
clrs=set_custom_palette(final['Accuracy'],max_color = 'crimson', other_color = 'b')
sns.barplot(x='Accuracy', y='Classifier', data=final, palette=clrs,color="b",)

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy After Hyper parameter tunning ')
plt.show()

# %%
# plotting the f1_Scores for each classifiers 
plt.figure(figsize=[10, 10])
# Data to be plotted
f1_nc = final["F1_score_NC"]
f1_mci = final["F1_score_NMCI"]

# Using numpy to group 3 different data with bars
X = np.arange(len(f1_nc))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
# changing color to dark khaki if it has highest value for f-score-nc
clrs = ["khaki" if (x < max(f1_nc)) else 'darkkhaki' for x in f1_nc ]
plt.barh(X, f1_nc, color = clrs, height = 0.25)
# changing color to dark salmon if it has highest value for f-score-ad
clrs = ["salmon" if (x < max(f1_mci)) else 'crimson' for x in f1_mci]
plt.barh(X + 0.25, f1_mci, color = clrs, height = 0.25)

# Creating the legend of the bars in the plot
plt.legend(['F1_score_NC', 'F1_score_MCI'])

plt.yticks([i + 0.25 for i in range(4)], ["SVC","RandomForestClassifier","DecisionTreeClassifier","XGBClassifier"])
# Giving the tilte for the plot
plt.title("Bar plot of F1_score For MCI vs NC")
# Namimg the x and y axis
plt.ylabel('Classifiers')
plt.xlabel('Scores')
plt.show()

# %%
# plotting the sensivity and specificity of different classifiers
plt.figure(figsize=[10, 10])
# Data to be plotted
sensi = final["Sensitivity_Score"]
speci = final["Specificity_Score"]

# Using numpy to group 3 different data with bars
X = np.arange(len(sensi))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
clrs = ['cadetblue' if (x < max(sensi)) else 'mediumseagreen' for x in sensi ]
plt.barh(X, sensi, color = clrs, height = 0.25)
clrs = ['thistle' if (x < max(speci)) else 'violet' for x in speci ]
plt.barh(X + 0.25, speci, color = clrs, height = 0.25)

# Creating the legend of the bars in the plot
plt.legend(['Sensitivity_Score', 'Specificity_Score'])

plt.yticks([i + 0.25 for i in range(4)], ["SVC","RandomForestClassifier","DecisionTreeClassifier","XGBClassifier"])
# Giving the tilte for the plot
plt.title("Bar plot of Sensitivity and Specificity in NC vs MCI")
# Naming the x and y axis
plt.ylabel('Classifiers')
plt.xlabel('Scores')
# Saving the plot as a 'png'
# plt.savefig('4BarPlot.png')
# Displaying the bar plot
plt.show()

# %% [markdown]
# ## Final Model for NC and MCI

# %%
# applying final models for NC vs MCI



X=combined_features_without_Scaling
X.shape
y=train_diagnose
y.shape


NC = np.where(train_diagnose == 1)[0]
print(NC.shape)

NMCI = np.where(train_diagnose == 2)[0]
print(NMCI.shape)

AD = np.where(train_diagnose == 3)[0]
print(AD.shape)
print("="*50)

NC_data_x = X[NC]
NC_data_y = y[NC]
print("-"*60)
print("Normal Control shape:",NC_data_x.shape)
print("Normal Control lable shape:",NC_data_y.shape)


NMCI_data_x =X[NMCI]
NMCI_data_y = y[NMCI]
print("-"*60)
print("NMCI shape:",NMCI_data_x.shape)
print("NMCI Y label:",NMCI_data_y.shape)

AD_data_x = X[AD]
AD_data_y = y[AD]
print("-"*60)
print("Alzheimer Disease shape :",AD_data_x.shape)
print("Alzheimer Disease Y label shape :",AD_data_y.shape)

print("="*50)
NC_data_x = X[NC]
NC_data_y = y[NC]
print("-"*60)
print("Normal Control shape:",NC_data_x.shape)
print("Normal Control lable shape:",NC_data_y.shape)


NMCI_data_x =X[NMCI]
NMCI_data_y = y[NMCI]
print("-"*60)
print("NMCI shape:",NMCI_data_x.shape)
print("NMCI Y label:",NMCI_data_y.shape)

AD_data_x = X[AD]
AD_data_y = y[AD]
print("-"*60)
print("Alzheimer Disease shape :",AD_data_x.shape)
print("Alzheimer Disease Y label shape :",AD_data_y.shape)

# %%
# concataning nc and MCi to apply classifiaction mdoels.

NCvsNMCI_X=np.concatenate((NMCI_data_x, NC_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NMCI_data_y, NC_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
# instaed of splitting it into three sets  of traning, test and valistion set , after finding the optimal classifer 
# combining twos sets of validation set and training set.
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X, NCvsNMCI_Y, test_size=0.20, random_state=123)

print("Training Set shape:",X_train.shape)

print("Test Set shape:",X_test.shape)

# %%
# sacling all fetuares to be on the same scale
scaler = MinMaxScaler(feature_range = (0, 1))
scaler.fit(X_train)
X_train=scaler.transform(X_train)

X_test=scaler.transform(X_test)
scaler.fit(X_test)
print("Alzheimer's diseas and Normal Train shape :",X_train.shape)
# print("Alzheimer's diseas and Normal Validation shape :",X_val.shape)
print("Alzheimer's diseas and Normal Test shape :",X_test.shape)

# %%
# applying pca to redcue 1600od to 150d
pca=PCA(150)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
var_exp = pca.explained_variance_ratio_

X_test_pca = pca.transform(X_test)

print("Total variance explianed by 150 components:", var_exp.sum())

# %%
# creating data frame to store all the metrics for evaluation .

Feature_imporatnce2=["Features","Training","Accuracy","F1_score_NC",'F1_score_NMCI',"Sensitivity_Score","Specificity Score","AUC Score"]
Feature_imporatnce_df2 = pd.DataFrame(columns=Feature_imporatnce2)

xgb_final = XGBClassifier(
        learning_rate=0.1, 
        max_depth=7, 
        n_estimators= 50,
        random_state=25,
        verbosity= 0,
       
)

xgb_final.fit(X_train_pca,y_train.ravel())

print('Accuracy of Training set: {:.2f}'.format(xgb_final.score(X_train_pca, y_train)))
print('Accuracy of Testing  set: {:.2f}'.format(xgb_final.score(X_test_pca,y_test)))


training= xgb_final.score(X_train_pca, y_train)
acc=xgb_final.score(X_test_pca,y_test)
train_predictions = xgb_final.predict(X_test_pca)
accuracy = accuracy_score(y_test.ravel(), train_predictions)
f1_scores1 = f1_score(y_test, train_predictions,pos_label=1)
f1_scores2 = f1_score(y_test, train_predictions,pos_label=2)
#     computing sensitivity,specificity from consuion matrix
confusion=confusion_matrix(y_test.ravel(), train_predictions)
#     getting TN from row 0 and column 0
TN = confusion[0][0]
#     getting FN from row 1 and column 0
FN = confusion[1][0]
#     getting TP from row 1 and column 1
TP = confusion[1][1]
#     getting FP from row 0 and column 1
FP = confusion[0][1]
#    sensitivity computed from TP divided by (False negative + True postive) 
sens=TP/(FN+TP)
#     specificity computed from TN divided by(True neagtive + False postive)
spec=TN/(TN+FP)
# predict probability for computing AUC
predic = xgb_final.predict_proba(X_test_pca)[:, 1]

#     AUC Score
auc = roc_auc_score(y_test.ravel(), predic)
  

# print("Accuracy {:.2%}".format(accuracy))
print("F1_Score of NC: {:.2%}".format(f1_scores1))
print("F1_Score of AD: {:.2%}".format(f1_scores2))
print("Sensitivity Score: {:.2%}".format(sens))
print("Specificity Score: {:.2%}".format(spec))
print("AUC Score: {:.2%}".format(auc))
feat_entry2 = pd.DataFrame([["With all Features",(xgb_final.score(X_train_pca, y_train))*100, accuracy*100,f1_scores1*100, f1_scores2*100,sens*100,spec*100,auc*100]], columns=Feature_imporatnce2)
Feature_imporatnce_df2 = Feature_imporatnce_df2.append(feat_entry2) 
Feature_imporatnce_df2

# %%
# plotting Auc Curve.
plt.style.use('fivethirtyeight')
plt.figure(figsize=(10,10))    
ax = plt.gca()
plot_roc_curve(dt_final,X_test_pca, y_test, ax=ax,color="red")
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of Normal Control vs MCI')

# %%
# plotting the metrics for final model of NC  and AD
x = ['Accuracy ', 'F1_score of NC', 'F1_Score of MCI',"Sensitivity_Score","Specificity Score","AUC Score"]
y = [accuracy, f1_scores1, f1_scores2,sens,spec,auc]
plt.figure(figsize=(10,10)) 
sns.set(style="darkgrid")
plt.title("Accuracy , F1-Scores,Sensitivity,Specificity and AUC of NC vs MCI")
sns.barplot(x, y)
plt.show()

# %%
from sklearn.metrics import confusion_matrix, classification_report
# Classfiaction report of teh final modeel of NC vs MCI
y_predict_svm =xgb_final.predict(X_test_pca)
print(classification_report(y_test.ravel(),y_predict_svm))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix


plt.title("Confusion Matrix of Normal Control vs MCI")
sns.heatmap(confusion_matrix(y_test, y_predict_svm ), fmt="d",cmap='Pastel2',annot = True)

# %% [markdown]
# # AD Vs MCI

# %%
# concatenating Ad and MCI to perform classification
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
ADvsNMCI_Y

# %%
from sklearn.model_selection import train_test_split
# splitting teh adta into val, test and trainings sets
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X, ADvsNMCI_Y, test_size=0.20, random_state=123)

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.10, random_state=123)

print("Training Set shape:",X_train.shape)
print("Validation Set shape:",X_val.shape)
print("Test Set shape:",X_test.shape)

# %%
# using MinMAx scaler so that all features be on the same sclae
scaler = MinMaxScaler(feature_range = (0, 1))
scaler.fit(X_train)
X_train=scaler.transform(X_train)
scaler.fit(X_val)
X_val=scaler.transform(X_val)
X_test=scaler.transform(X_test)
scaler.fit(X_test)
print("Alzheimer's diseas and Normal Train shape :",X_train.shape)
print("Alzheimer's diseas and Normal Validation shape :",X_val.shape)
print("Alzheimer's diseas and Normal Test shape :",X_test.shape)

# %%
# applying classfiers of svm , decision tree, random froest and XGboost with their default parameters
classifiers = [
    SVC(random_state=25 ,probability=True),
    DecisionTreeClassifier(random_state=25),
    RandomForestClassifier(random_state=25),
    XGBClassifier(random_state=25),
    ]

# %%
# %%time

models_cols=["Classifiers", "Accuracy","F1_score_NMCI", "F1_score_AD"]
models_df = pd.DataFrame(columns=models_cols)
# creating for loop  models be fitted and metrics computed for each mdoels
for models in classifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_val)
    trainingscore=models.score(X_train, y_train)
    accuracy = accuracy_score(y_val.ravel(), train_predictions)
    f1_scores1 = f1_score(y_val.ravel(), train_predictions,pos_label=2.0)
    f1_scores2 = f1_score(y_val.ravel(), train_predictions,pos_label=3.0)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NMCI: {:.2%}".format(f1_scores1))
    print("F1_Score of AD: {:.2%}".format(f1_scores2))
#     saving teh rseult in models_Df data frame.
    models_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100]], columns=models_cols)
    models_df = models_df.append(models_entry)
    
    
    
print("="*30)

# %%
plt.style.use('fivethirtyeight')
# plotting ROC curve fro each models.
plt.figure(figsize=(10,10))    
ax = plt.gca()
for i in classifiers:
    plot_roc_curve(i, X_val, y_val, ax=ax)
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of AD vs MCI BEFORE PCA')

# %%
# comapringa accuarcy of each models before applying PCA
sns.set_color_codes("dark")
clrs=set_custom_palette(models_df['Accuracy'],max_color = 'crimson', other_color = 'b')
sns.barplot(x='Accuracy', y='Classifiers', data=models_df, palette=clrs,color="b",)

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy Before PCA of AD vs MCI ')
plt.show()

# %%
# comapringa f1_Score of each models before applying PCA
sns.set_color_codes("dark")
clrs=set_custom_palette(models_df['F1_score_NMCI'],max_color = 'crimson', other_color = 'orange')
sns.barplot(x='F1_score_NMCI', y='Classifiers', data=models_df,palette=clrs, color="orange")

plt.xlabel('F1-Score %')
plt.title('MCI F1-Score')
plt.show()

sns.set_color_codes("muted")
clrs=set_custom_palette(models_df['F1_score_AD'],max_color = 'crimson', other_color = 'y')
sns.barplot(x='F1_score_AD', y='Classifiers', data=models_df,palette=clrs, color="y")

plt.xlabel('F1-Score %')
plt.title('Alzheimer Disease F1-Score')
plt.show()

# %%
# applying PCA
pca=PCA(150)
pca.fit(X_train)
X_train_pca = pca.transform(X_train)
var_exp = pca.explained_variance_ratio_
X_val_pca=pca.transform(X_val)
X_test_pca = pca.transform(X_test)
print("Total variance explianed by 150 components:", var_exp.sum())

# %%
# %%time
# creating df sao that all result will be saved in data frame and be comapred later on.
models_cols=["Classifiers", "Accuracy","F1_score_NMCI", "F1_score_AD"]
models_df = pd.DataFrame(columns=models_cols)

for models in classifiers:
    models.fit(X_train_pca, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_val_pca)
    trainingscore=models.score(X_train_pca, y_train)
    accuracy = accuracy_score(y_val.ravel(), train_predictions)
    f1_scores1 = f1_score(y_val.ravel(), train_predictions,pos_label=2.0)
    f1_scores2 = f1_score(y_val.ravel(), train_predictions,pos_label=3.0)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NMCI: {:.2%}".format(f1_scores1))
    print("F1_Score of AD: {:.2%}".format(f1_scores2))
    models_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100]], columns=models_cols)
    models_df = models_df.append(models_entry)
    
    
    
print("="*30)

# %%
# comparing accuracy of each models after PCA
sns.set_color_codes("pastel")
clrs=set_custom_palette(models_df['Accuracy'],max_color = 'crimson', other_color = 'navy')
sns.barplot(x='Accuracy', y='Classifiers', data=models_df, palette=clrs,color="navy",)

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy AFTER PCA of AD vs MCI ')
plt.show()

# %% [markdown]
# # AD vs MCI HYPERPARAMTER TUNNING

# %% [markdown]
# ## SVM HYPERPARAMTER TUNNING

# %%
# %%time


# HYPERPARAMTER TUNNING svm with diffreent values.
cross_valid_scores = {}
best_estimator_Score={}
parameters = {
    "C": [0.001, 0.01, 0.1, 1.],
    "kernel": ["linear", "poly", "rbf", "sigmoid"],
    "gamma": ["scale", "auto"],
}

model_svc = SVC(
    random_state=25,
    class_weight="balanced",
    probability=True,
)

model_svc = GridSearchCV(
    model_svc, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_svc.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_svc.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + 
    f'{model_svc.best_score_:.3f}'
)
cross_valid_scores['svc'] = model_svc.best_score_


# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_svc.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['SVM Model']=model_svc.best_estimator_.score(X_val_pca, y_val)

print('-----')

# %% [markdown]
# ## Desicion Tree HYPERPARAMTER TUNNING

# %%
# %%time
parameters = {
    "criterion":["gini","entropy"],
    "max_depth":range(1,20),
    "min_samples_split":range(2,10),
    "min_samples_leaf":range(1,5)
                      
}

model_desicion_tree = DecisionTreeClassifier(
    random_state=25
)

model_desicion_tree = GridSearchCV(
    model_desicion_tree, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_desicion_tree.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_desicion_tree.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + \
    f'{model_desicion_tree.best_score_:.3f}'
)
cross_valid_scores['desicion_tree'] = model_desicion_tree.best_score_
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_desicion_tree.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['Desicion_tree']=model_desicion_tree.best_estimator_.score(X_val_pca, y_val)


print('-----')

# %% [markdown]
# #  Random Forest HYPERPARAMTERER TUNNING

# %%
# %%time
parameters = {
    "n_estimators": [5, 10, 15, 20, 25], 
    "max_features":range(5,11),
    "bootstrap":[True,False],
    "max_depth": [3, 5, 7, 9, 11, 13],
    
}


model_random_forest = RandomForestClassifier(
    random_state=25,
    class_weight='balanced',
)

model_random_forest = GridSearchCV(
    model_random_forest, 
    parameters, 
    cv=5,
    scoring='accuracy',
)

model_random_forest.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_random_forest.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: '+ \
    f'{model_random_forest.best_score_:.3f}'
)
cross_valid_scores['random_forest'] = model_random_forest.best_score_
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_random_forest.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['Random_Forest']=model_random_forest.best_estimator_.score(X_val_pca, y_val)


print('-----')

# %% [markdown]
# #  XGBOOST HYPERPARAMETER TUNNING

# %%
# %%time
parameters = {
    'max_depth': [3, 5, 7, 9], 
    'n_estimators': [5, 10, 15, 20, 25, 50, 100],
    'learning_rate': [0.01, 0.05, 0.1],
    'verbosity': [0]
}

model_xgb = XGBClassifier(
    random_state=25,
)

model_xgb = GridSearchCV(
    model_xgb, 
    parameters, 
    cv=5,
    scoring='accuracy',
     # add this line to slient warning message
)

model_xgb.fit(X_train_pca, y_train.ravel())

print('-----')
print(f'Best parameters {model_xgb.best_params_}')
print(
    f'Mean cross-validated accuracy score of the best_estimator: ' + 
    f'{model_xgb.best_score_:.3f}'
)
cross_valid_scores['xgboost'] = model_xgb.best_score_
# using validation set to test the best estimator
print('Best estimator score on Validation set : %.3f'%model_xgb.best_estimator_.score(X_val_pca, y_val))

best_estimator_Score['XG-Boost Model']=model_xgb.best_estimator_.score(X_val_pca, y_val)

print('-----')

# %%
pd.DataFrame(cross_valid_scores, index=['Best Accuracy Through Grid Search ']).T

# %% [markdown]
# ## Applying Best Paramaters for each models after Hyper Paramater tunning.

# %%
# Create the final SVM Classifier

finalClassifiers=[]
svc_final = SVC(
    random_state=25,
    class_weight="balanced",
    probability=True,
    C= 1.0, 
    gamma= 'scale',
    kernel= 'rbf'
)


# Create the final Random Forest
rf_final = RandomForestClassifier(
            random_state=25,
            class_weight='balanced',
            max_depth=5,
            max_features=7,
            n_estimators= 20
)


# Create the final Random Forest
dt_final = DecisionTreeClassifier(
            criterion='gini',
            max_depth=5,
            min_samples_leaf=4,
            min_samples_split=9,
            random_state=25
)


# Create the fnal Extreme Gradient Booster
xgb_final = XGBClassifier(
        learning_rate=0.1, 
        max_depth=7, 
        n_estimators= 15,
        random_state=25,
        verbosity= 0,
       
)

# %%
from sklearn.metrics import f1_score, confusion_matrix
finalClassifiers = [svc_final, rf_final, dt_final,xgb_final]
final_cols=["Classifier", "Accuracy","F1_score_NMCI", "F1_score_AD","Sensitivity_Score","Specificity Score","AUC"]
final = pd.DataFrame(columns=final_cols)
for models in finalClassifiers:
    models.fit(X_train_pca, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test_pca)
    trainingscore=models.score(X_train_pca, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    f1_scores1 = f1_score(y_test.ravel(), train_predictions,pos_label=2.0)
    f1_scores2 = f1_score(y_test.ravel(), train_predictions,pos_label=3.0)
#     computing sensitivity,specificity from consuion matrix
    confusion=confusion_matrix(y_test.ravel(), train_predictions)
#     getting TN from row 0 and column 0
    TN = confusion[0][0]
#     getting FN from row 1 and column 0
    FN = confusion[1][0]
#     getting TP from row 1 and column 1
    TP = confusion[1][1]
#     getting FP from row 0 and column 1
    FP = confusion[0][1]
#    sensitivity computed from TP divided by (False negative + True postive) 
    sens=TP/(FN+TP)
#     specificity computed from TN divided by(True neagtive + False postive)
    spec=TN/(TN+FP)
    predic = models.predict_proba(X_test_pca)[:, 1]

#     AUC Score
    auc = roc_auc_score(y_test.ravel(), predic)
    
  
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    print("F1_Score of NC: {:.2%}".format(f1_scores1))
    print("F1_Score of AD: {:.2%}".format(f1_scores2))
    print("Sensitivity Score: {:.2%}".format(sens))
    print("Specificity Score: {:.2%}".format(spec))
    print("AUC Score: {:.2%}".format(auc))
# saving the result into final model data frame.
    final_entry = pd.DataFrame([[name, accuracy*100,f1_scores1*100, f1_scores2*100,sens*100,spec*100,auc*100]], columns=final_cols)
    final = final.append(final_entry )
print("="*30)


final

# %%
plt.style.use('fivethirtyeight')
# plotting ROC curve for each models.
plt.figure(figsize=(10,10))    
ax = plt.gca()
for i in finalClassifiers:
    plot_roc_curve(i, X_test_pca, y_test, ax=ax)
plt.plot([0, 1], [0, 1],'r--',color="blue")
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])    
plt.title('AUC score of AD vs MCI AFTER Hyper-Parameter Tunning.')

# %%
# comparing accuracys core of each models after hypeer parameter tunning .
sns.set_color_codes("muted")
clrs=set_custom_palette(final['Accuracy'],max_color = 'crimson', other_color = 'b')
sns.barplot(x='Accuracy', y='Classifier', data=final, palette=clrs,color="b",)

plt.xlabel('Accuracy %')
plt.title('Classifier Accuracy After Hyper parameter tunning  of MCI vs AD')
plt.show()

# %%
# Declaring the figure or the plot (y, x) or (width, height)
plt.figure(figsize=[10, 10])
# Data to be plotted

f1_mci = final["F1_score_NMCI"]
f1_ad = final["F1_score_AD"]

# Using numpy to group 3 different data with bars
X = np.arange(len(f1_nc))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
# changing color to dark khaki if it has highest value for f-score-nc
clrs = ["khaki" if (x < max(f1_mci)) else 'darkkhaki' for x in f1_mci ]
plt.barh(X, f1_mci, color = clrs, height = 0.25)
# changing color to dark salmon if it has highest value for f-score-ad
clrs = ["salmon" if (x < max(f1_ad)) else 'darksalmon' for x in f1_ad]
plt.barh(X + 0.25, f1_ad, color = clrs, height = 0.25)

# Creating the legend of the bars in the plot
plt.legend(['F1_score_MCI', 'F1_score_AD'])

plt.yticks([i + 0.25 for i in range(4)], ["SVC","RandomForestClassifier","DecisionTreeClassifier","XGBClassifier"])
# Giving the tilte for the plot
plt.title("Bar plot of F1_score For MCI vs AD")
# Namimg the x and y axis
plt.ylabel('Classifiers')
plt.xlabel('Scores')
# Saving the plot as a 'png'
# plt.savefig('4BarPlot.png')
# Displaying the bar plot
plt.show()

# %%
# Declaring the figure or the plot (y, x) or (width, height)
plt.figure(figsize=[10, 10])
# Data to be plotted
sensi = final["Sensitivity_Score"]
speci = final["Specificity Score"]

# Using numpy to group 3 different data with bars
X = np.arange(len(sensi))
# Passing the parameters to the bar function, this is the main function which creates the bar plot
# Using X now to align the bars side by side
clrs = ['cadetblue' if (x < max(sensi)) else 'mediumseagreen' for x in sensi ]
plt.barh(X, sensi, color = clrs, height = 0.25)
clrs = ['thistle' if (x < max(speci)) else 'crimson' for x in speci ]
plt.barh(X + 0.25, speci, color = clrs, height = 0.25)

# Creating the legend of the bars in the plot
plt.legend(['Sensitivity_Score', 'Specificity_Score'])

plt.yticks([i + 0.25 for i in range(4)], ["SVC","RandomForestClassifier","DecisionTreeClassifier","XGBClassifier"])
# Giving the tilte for the plot
plt.title("Bar plot of Sensitivity and Specificity in MCI vs AD")
# Naming the x and y axis
plt.ylabel('Classifiers')
plt.xlabel('Scores')
# Saving the plot as a 'png'
# plt.savefig('4BarPlot.png')
# Displaying the bar plot
plt.show()

# %% [markdown]
# ## Feature importance testing by removing one measurement each time.

# %%
from sklearn.pipeline import Pipeline
# creating a pipline to scale and redcue the dimensionality of all fetaures.
pipe = Pipeline([('scaler', MinMaxScaler(feature_range = (0, 1))),
                 ('pca', PCA(30))])

# %%
# applying the pipline to Fa feature to reduce its dimensilaity from 16000 to 30 
fa_feature_all_locations_scalPca=pipe.fit_transform(fa_feature_all_locations_without_Nan)
print(fa_feature_all_locations_scalPca.shape)
# applying the pipline to MD feature to reduce its dimensilaity from 16000 to 30 
md_feature_all_locations_scalPca=pipe.fit_transform(md_feature_all_locations_without_Nan)
print(md_feature_all_locations_scalPca.shape)
# applying the pipline to RD feature to reduce its dimensilaity from 16000 to 30 
rd_feature_all_locations_scalPca=pipe.fit_transform(rd_feature_all_locations_without_Nan)
print(rd_feature_all_locations_scalPca.shape)
# applying the pipline to AD feature to reduce its dimensilaity from 16000 to 30 
ad_feature_all_locations_scalPca=pipe.fit_transform(ad_feature_all_locations_without_Nan)
print(ad_feature_all_locations_scalPca.shape)
# applying the pipline to CL feature to reduce its dimensilaity from 16000 to 30 
cl_feature_all_locations_scalPca=pipe.fit_transform(cl_feature_all_locations_without_Nan)
print(cl_feature_all_locations_scalPca.shape)
# applying the pipline to curvature feature to reduce its dimensilaity from 16000 to 30 
curvature_feature_all_locations_scalPca=pipe.fit_transform(curvature_feature_all_locations_without_Nan)
print(curvature_feature_all_locations_scalPca.shape)
# applying the pipline to Torsion feature to reduce its dimensilaity from 16000 to 30 
Torsion_feature_all_locations_scalPca=pipe.fit_transform(Torsion_feature_all_locations_without_Nan)
print(Torsion_feature_all_locations_scalPca.shape)
# applying the pipline to Volume feature to reduce its dimensilaity from 16000 to 30 
volume_feature_all_locations_scalPca=pipe.fit_transform(volume_feature_all_locations_without_Nan)
print(volume_feature_all_locations_scalPca.shape)

# %%
# correcting mistakes of not using replaced nan values 
combined_features_scalPca=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
# X=combined_features_without_Scaling
# X.shape
y=train_diagnose
y.shape



NMCI_data_x =combined_features_scalPca[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_features_scalPca[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
# combining AD and MCI
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
# splitting data into tarining , testing .
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    feature_entry.append([accuracy*100])
    
#     featureImportance_df["Without_FA"]=feature_entry[0:4]
    FeatureImportance_all=pd.DataFrame(feature_entry[0:4],columns=["All Features"])

    
print("="*30)
FeatureImportance_all.head(5)

# # feature_entry[0:4]
# FeatureImportance_FA

# %% [markdown]
# ## AD vs NMCI Training without FA

# %%
np.random.seed(500)
#removing Fa from the data
combined_FA_Ex=np.concatenate((md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
# X=combined_features_without_Scaling
# X.shape
y=train_diagnose
y.shape
NC_data_x = combined_FA_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_FA_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_FA_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
# combining AD and MCI
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
# splitting data into tarining , testing .
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
# finalClassifiers = [svc_final, rf_final, dt_final,xgb_final]
# featureImportance_cols=["Classifiers"]
# featureImportance_df = pd.DataFrame(columns=featureImportance_cols)
# feature_entry=[]
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    feature_entry.append([accuracy*100])
    
#     featureImportance_df["Without_FA"]=feature_entry[0:4]
    FeatureImportance_FA=pd.DataFrame(feature_entry[0:4],columns=["Without_FA"])

    
print("="*30)
# featureImportance_df.head(5)

# feature_entry[0:4]
FeatureImportance_FA

# %% [markdown]
# ## AD vs NMCI Training without MD

# %%
#removing MD from the data
combined_MD_Ex=np.concatenate((fa_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NMCI_data_x =combined_MD_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_MD_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
# featureImportance_cols=["Classifiers","Without_FA"]
# featureImportance_df = pd.DataFrame(columns=featureImportance_cols)
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_MD=pd.DataFrame(feature_entry[0:4],columns=["Without_MA"])
    
print("="*30)
FeatureImportance_MD

# %% [markdown]
# ## AD vs NMCI Training without RD

# %%
#removing RD from the data
combined_RD_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NMCI_data_x =combined_RD_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_RD_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_RD=pd.DataFrame(feature_entry[0:4],columns=["Without_RD"])
    
print("="*30)
FeatureImportance_RD

# %%
def models_trining_testing(X_train,y_train,X_test,y_test):
    feature_entry=[]
    for models in finalClassifiers:
        models.fit(X_train, y_train.ravel())
        name = models.__class__.__name__
        print("="*30)
        print(name)
        print('****Results****')
        train_predictions = models.predict(X_test)
        trainingscore=models.score(X_train, y_train.ravel())
        accuracy = accuracy_score(y_test.ravel(), train_predictions)
        print("Training {:.2%}".format(trainingscore))
        print("Accuracy {:.2%}".format(accuracy))
        feature_entry.append([accuracy*100])
        FeatureImportance_RD=pd.DataFrame(feature_entry[0:4],columns=["Without_RD"])
    
# print("="*30)
# FeatureImportance_RD
testing=models_trining_testing(X_train,y_train,X_test,y_test)
testing

# %% [markdown]
# # AD vs MCI Training without AD

# %%
#removing AD from the data
combined_AD_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_AD_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_AD_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_AD_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_AD=pd.DataFrame(feature_entry[0:4],columns=["Without_AD"])
    
print("="*30)
FeatureImportance_AD

# %% [markdown]
# # AD vs MCI Training without CL

# %%
#removing cl from the data
combined_CL_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_CL_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_CL_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_CL_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_CL=pd.DataFrame(feature_entry[0:4],columns=["Without_CL"])
    
print("="*30)
FeatureImportance_CL

# %% [markdown]
# # AD vs MCI Training without Curvature

# %%
#removing Curvature from the data
combined_CUR_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_CUR_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_CUR_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_CUR_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_cur=pd.DataFrame(feature_entry[0:4],columns=["Without_Curvature"])
    
print("="*30)
FeatureImportance_cur

# %% [markdown]
# # AD vs MCI Training without Torsion

# %%
#removing Torsion from the data
combined_Tor_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_Tor_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_Tor_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_Tor_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_tor=pd.DataFrame(feature_entry[0:4],columns=["Without_Torsion"])
    
print("="*30)
FeatureImportance_tor

# %% [markdown]
# # AD vs MCI Training without Volume

# %%
#removing Volume from the data
combined_Vol_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_Vol_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_Vol_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

AD_data_x = combined_Vol_Ex[AD]
AD_data_y = y[AD]

print(AD_data_x.shape)
print(AD_data_y.shape)

# %%
ADvsNMCI_X=np.concatenate((AD_data_x, NMCI_data_x), axis=0)
print(ADvsNMCI_X.shape)

ADvsNMCI_Y=np.concatenate((AD_data_y, NMCI_data_y), axis=0)
print(ADvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(ADvsNMCI_X,ADvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_vol=pd.DataFrame(feature_entry[0:4],columns=["Without_Volume"])
    classifierss=["SVM","Random_Forest","Decision_Tree","XG_Boost"]
    classifierss_df=pd.DataFrame(classifierss[0:4],columns=["Models"])
    
print("="*30)
FeatureImportance_all=pd.concat((classifierss_df,FeatureImportance_all,FeatureImportance_FA,FeatureImportance_MD,FeatureImportance_RD,FeatureImportance_AD,FeatureImportance_CL,FeatureImportance_cur,FeatureImportance_tor,FeatureImportance_vol),axis=1)
# FeatureImportance_all
df_t = FeatureImportance_all.T
#grab the first row for the column
df_t=df_t.rename(columns=df_t.iloc[0])
df_t=df_t[1:] #take the data less the header row
df_t

# %%
barplot=df_t.plot(kind='barh',figsize=(20,20),width=.8,color=["darkseagreen","powderblue","cornflowerblue","tan"])

# for loop to get the accuracy text label by using the widthvalue of the bars
for p in barplot.patches:
                _x = p.get_x() + p.get_width() 
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                barplot.text(_x, _y, value, ha="left")
# Giving the title for the plot
plt.title("Bar plot representing the Features Importance of AD vs MCI")
# Namimg the x and y axis
plt.ylabel('Features')
plt.xlabel('Scores')
plt.show()

# %% [markdown]
# # NC vs MCI  Feature Importance.

# %% [markdown]
# ## Feature importance testing by removing one measurement each time.

# %%
combined_features_withScalPCA=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
# Normal Control vs MCI
y=train_diagnose
y.shape
NC_data_x = combined_features_withScalPCA[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_features_withScalPCA[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
# splitting data into tarining , testing .
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
    feature_entry.append([accuracy*100])
    

    FeatureImportance_all=pd.DataFrame(feature_entry[0:4],columns=["All Features"])

    
print("="*30)
FeatureImportance_all.head(5)

# %% [markdown]
# ## NC vs NMCI Training without FA

# %%
#removing Fa from the data
combined_FA_Ex=np.concatenate((md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
# X=combined_features_without_Scaling
# X.shape
y=train_diagnose
y.shape
NC_data_x = combined_FA_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_FA_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
# splitting data into tarining , testing .
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
# making a list tos ave the result to it
feature_entry=[]
# for loop for traning and testing of the four models
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
#     appeending the accauracy of the models into the feature_entry
    feature_entry.append([accuracy*100])
# saving the feature importanc einto data frame.
    FeatureImportance_FA=pd.DataFrame(feature_entry[0:4],columns=["Without_FA"])

    
print("="*30)

FeatureImportance_FA

# %% [markdown]
# ## NC  vs NMCI Training without MD

# %%
#removing MD from the data
combined_MD_Ex=np.concatenate((fa_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_MD_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_MD_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
# list to save the accuarcy of the models
feature_entry=[]

# for loop for training and testing all four models and then saving teh result to the list mentioned above
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    # appending the accauracy of the models into the feature_entry
    feature_entry.append([accuracy*100])
    # saving the feature importanc einto data frame.

    FeatureImportance_MD=pd.DataFrame(feature_entry[0:4],columns=["Without_MA"])
    
print("="*30)
FeatureImportance_MD

# %% [markdown]
# ## NC  vs NMCI Training without RD

# %%
#removing RD from the data
combined_RD_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_RD_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_RD_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
 # list to save the accuarcy of the models
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))
  
    # appending the accauracy of the models into the feature_entry
    feature_entry.append([accuracy*100])
    # saving the feature importanc einto data frame.

    FeatureImportance_RD=pd.DataFrame(feature_entry[0:4],columns=["Without_RD"])
    
print("="*30)
FeatureImportance_RD

# %% [markdown]
# # NC  vs MCI Training without AD

# %%
#removing AD from the data
combined_AD_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_AD_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_AD_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_AD=pd.DataFrame(feature_entry[0:4],columns=["Without_AD"])
    
print("="*30)
FeatureImportance_AD

# %% [markdown]
# # NC vs MCI Training without CL

# %%
#removing cl from the data
combined_CL_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_CL_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_CL_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_CL=pd.DataFrame(feature_entry[0:4],columns=["Without_CL"])
    
print("="*30)
FeatureImportance_CL

# %% [markdown]
# # NC  vs MCI Training without Curvature

# %%
#removing Curvature from the data
combined_CUR_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca,volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_CUR_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_CUR_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_cur=pd.DataFrame(feature_entry[0:4],columns=["Without_Curvature"])
    
print("="*30)
FeatureImportance_cur

# %% [markdown]
# # NC vs MCI Training without Torsion

# %%
#removing Torsion from the data
combined_Tor_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        volume_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_Tor_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_Tor_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_tor=pd.DataFrame(feature_entry[0:4],columns=["Without_Torsion"])
    
print("="*30)
FeatureImportance_tor

# %% [markdown]
# # NC  vs MCI Training without Volume

# %%
#removing Volume from the data
combined_Vol_Ex=np.concatenate((fa_feature_all_locations_scalPca,md_feature_all_locations_scalPca,rd_feature_all_locations_scalPca, 
                        ad_feature_all_locations_scalPca,cl_feature_all_locations_scalPca,curvature_feature_all_locations_scalPca,
                        Torsion_feature_all_locations_scalPca),axis=1)

# %%
NC_data_x = combined_Vol_Ex[NC]
NC_data_y = y[NC]

print(NC_data_x.shape)
print(NC_data_y.shape)


NMCI_data_x =combined_Vol_Ex[NMCI]
NMCI_data_y = y[NMCI]

print(NMCI_data_x.shape)
print(NMCI_data_y.shape)

# %%
# Normal control and MCI
NCvsNMCI_X=np.concatenate((NC_data_x, NMCI_data_x), axis=0)
print(NCvsNMCI_X.shape)

NCvsNMCI_Y=np.concatenate((NC_data_y, NMCI_data_y), axis=0)
print(NCvsNMCI_Y.shape)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(NCvsNMCI_X,NCvsNMCI_Y, test_size=0.20, random_state=123)
print(X_train.shape)
print(X_test.shape)

# %%
feature_entry=[]
for models in finalClassifiers:
    models.fit(X_train, y_train.ravel())
    name = models.__class__.__name__
    
    print("="*30)
    print(name)
    
    print('****Results****')
    train_predictions = models.predict(X_test)
    trainingscore=models.score(X_train, y_train.ravel())
    accuracy = accuracy_score(y_test.ravel(), train_predictions)
    print("Training {:.2%}".format(trainingscore))
    print("Accuracy {:.2%}".format(accuracy))

    feature_entry.append([accuracy*100])

    FeatureImportance_vol=pd.DataFrame(feature_entry[0:4],columns=["Without_Volume"])
    classifierss=["SVM","Random_Forest","Decision_Tree","XG_Boost"]
    classifierss_df=pd.DataFrame(classifierss[0:4],columns=["Models"])
    
print("="*30)
FeatureImportance_all=pd.concat((classifierss_df,FeatureImportance_all,FeatureImportance_FA,FeatureImportance_MD,FeatureImportance_RD,FeatureImportance_AD,FeatureImportance_CL,FeatureImportance_cur,FeatureImportance_tor,FeatureImportance_vol),axis=1)
# FeatureImportance_all
df_t = FeatureImportance_all.T
#grab the first row for the column
df_t=df_t.rename(columns=df_t.iloc[0])
df_t=df_t[1:] #take the data less the header row
df_t

# %%
barplot=df_t.plot(kind='barh',figsize=(20,20),width=.8,color=["khaki","thistle","cadetblue","r"])

for p in barplot.patches:
                _x = p.get_x() + p.get_width() 
               
                _y = p.get_y() + p.get_height()

                value = int(p.get_width())
                barplot.text(_x, _y, value, ha="left")
# Giving the title for the plot
plt.title("Bar plot representing the Features Importance of NC vs MCI")
# Namimg the x and y axis
plt.ylabel('Features')
plt.xlabel('Scores')
plt.show()
